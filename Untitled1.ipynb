# %%
# !pip install requests-html
# Out:
# ...
#   Using cached bs4-0.0.1-py3-none-any.whl
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=4a05c5dfc98c1f0f2150cb51d540ecdc64c462709e3994d0a7309aaff120f205
#   Stored in directory: c:\users\vishal\appdata\local\pip\cache\wheels\ed\f7\62\50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=fd7361637f3b2921eb01d43a239ff2fa511a987c47ba71b99c380b9ede34d1b6
#   Stored in directory: c:\users\vishal\appdata\local\pip\cache\wheels\9c\aa\cc\f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent parse
# ...

# %%
import requests
from requests_html import HTML

# %%
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'python'
query_filter = 'Frequent'
url = f'{base_url}{tag}?tab={query_filter}'
url
# Out:
# 'https://stackoverflow.com/questions/tagged/python'

# %%
r = requests.get(url)
html_str = r.text

# %%
html = HTML(html = html_str)

# %%
question_summary = html.find(class_="s-post-summary js-post-summary")
question_summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3652\2305561745.py in <module>
# ----> 1 question_summary = html.find("div", {"class": "s-post-summary js-post-summary"})
#       2 question_summary
#
# TypeError: find() takes from 1 to 2 positional arguments but 3 were given

# %%
# import the required libraries
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import requests

# %%
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'python'
query_filter = 'Frequent'
url = f'{base_url}{tag}?tab={query_filter}'
url
# Out:
# 'https://stackoverflow.com/questions/tagged/python?tab=Frequent'

# %%
page = requests.get(url)

# %%
page.text
# Out:
# '<!DOCTYPE html>\r\n\r\n\r\n    <html class="html__responsive " lang="en">\r\n\r\n    <head>\r\n\r\n        <title>Frequent &#39;python&#39; Questions - Stack Overflow</title>\r\n        <link rel="shortcut icon" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196">\r\n        <link rel="apple-touch-icon" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a">\r\n        <link rel="image_src" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a"> \r\n        <link rel="search" type="application/opensearchdescription+xml" title="Stack Overflow" href="/opensearch.xml">\r\n    <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0">\r\n        <meta property="og:type" content= "website" />\r\n        <meta property="og:url" content="https://stackoverflow.com/questions/tagged/python?tab=Frequent"/>\r\n        <meta property="og:site_
# ...

# %%
# Install driver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [C:\Users\Vishal\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
driver.get(url)

# %%
time.sleep(3)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
print(soup.prettify())
# Out:
# <html class="html__responsive" lang="en">
#  <head>
#   <title>
#    Frequent 'python' Questions - Stack Overflow
#   </title>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
#   <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
#   <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://stackoverflow.com/questions/tagged/python?tab=Frequent" property="og:url"/>
#   <meta content="Stack Overflow" property="og:site_name"/>
# ...

# %%
question_classes = soup.find(class_='flush-left')
question_classes
# Out:
# <div class="flush-left" id="questions">
# <div class="s-post-summary js-post-summary" data-post-id="20109391" data-post-type-id="1" id="question-summary-20109391">
# <div class="s-post-summary--stats js-post-summary-stats">
# <div class="s-post-summary--stats-item s-post-summary--stats-item__emphasized" title="Score of 220">
# <span class="s-post-summary--stats-item-number">220</span>
# <span class="s-post-summary--stats-item-unit">votes</span>
# </div>
# <div class="s-post-summary--stats-item has-answers has-accepted-answer" title="one of the answers was accepted as the correct answer">
# <svg aria-hidden="true" class="svg-icon iconCheckmarkSm" height="14" viewbox="0 0 14 14" width="14"><path d="M13 3.41 11.59 2 5 8.59 2.41 6 1 7.41l4 4 8-8Z"></path></svg> <span class="s-post-summary--stats-item-number">5</span>
# <span class="s-post-summary--stats-item-unit">answers</span>
# </div>
# <div class="s-post-summary--stats-item is-hot" title="40293 views">
# ...

# %%
question_summaries = soup.find(class_='s-post-summary js-post-summary')
question_summaries
# Out:
# <div class="s-post-summary js-post-summary" data-post-id="20109391" data-post-type-id="1" id="question-summary-20109391">
# <div class="s-post-summary--stats js-post-summary-stats">
# <div class="s-post-summary--stats-item s-post-summary--stats-item__emphasized" title="Score of 220">
# <span class="s-post-summary--stats-item-number">220</span>
# <span class="s-post-summary--stats-item-unit">votes</span>
# </div>
# <div class="s-post-summary--stats-item has-answers has-accepted-answer" title="one of the answers was accepted as the correct answer">
# <svg aria-hidden="true" class="svg-icon iconCheckmarkSm" height="14" viewbox="0 0 14 14" width="14"><path d="M13 3.41 11.59 2 5 8.59 2.41 6 1 7.41l4 4 8-8Z"></path></svg> <span class="s-post-summary--stats-item-number">5</span>
# <span class="s-post-summary--stats-item-unit">answers</span>
# </div>
# <div class="s-post-summary--stats-item is-hot" title="40293 views">
# <span class="s-post-summary--stats-item-number">40k</span>
# ...

# %%
for question_summary in question_summaries:
    specfic_class = soup.find(class_ = 's-post-summary--content-title')
    print(specfic_class)
# Out:
# <h3 class="s-post-summary--content-title">
# <a class="s-link" href="/questions/20109391/how-to-make-good-reproducible-pandas-examples">How to make good reproducible pandas examples</a>
# </h3>
# <h3 class="s-post-summary--content-title">
# <a class="s-link" href="/questions/20109391/how-to-make-good-reproducible-pandas-examples">How to make good reproducible pandas examples</a>
# </h3>
# <h3 class="s-post-summary--content-title">
# <a class="s-link" href="/questions/20109391/how-to-make-good-reproducible-pandas-examples">How to make good reproducible pandas examples</a>
# </h3>
# <h3 class="s-post-summary--content-title">
# <a class="s-link" href="/questions/20109391/how-to-make-good-reproducible-pandas-examples">How to make good reproducible pandas examples</a>
# </h3>
# <h3 class="s-post-summary--content-title">
# <a class="s-link" href="/questions/20109391/how-to-make-good-reproducible-pandas-examples">How to make good reproducible pandas examples</a>
# </h3>
# ...

# %%
specfic_class.text.replace('\n', '')
# Out:
# 'How to make good reproducible pandas examples'
