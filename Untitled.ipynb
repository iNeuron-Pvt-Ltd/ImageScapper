# %%
import os
import time
import requests
import selenium
import time
import io
from PIL import Image
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException

# %%
# Install driver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\Vishal\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %% [markdown]
# # Instagram Scrapper

# %%
import instagramy

# %%
user = instagramy.InstagramUser('c17hawke')

# %%
print(user.number_of_followers)
# Out:
# 839

# %%
print(user.is_verified)
# Out:
# False

# %%
print(user.biography)
# Out:
# A Data Scientist with an Artistic touch :D

# %%
# return the list of dicts
posts = user.posts
for post in posts:
    likes = post.likes
    comments = post.comments
    print(likes, comments)
# Out:
# 116 3
# 91 2
# 100 3
# 66 4
# 66 3
# 69 2
# 56 6
# 73 16
# 46 2
# 63 3
# 75 3
# 63 10

# %%
for post in posts:
    print(post)
# Out:
# Post(likes=116, comments=3, caption=None, is_video=True, timestamp=1649273370, location=None, shortcode='CcBWuwmjWHR', post_url='https://www.instagram.com/p/CcBWuwmjWHR/', display_url='https://scontent-maa2-1.cdninstagram.com/v/t51.2885-15/277897061_1203771603494966_7269208377252231368_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-maa2-1.cdninstagram.com&_nc_cat=102&_nc_ohc=FEsb-_df_p8AX97X4Hu&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT8TeU5W2CLgp9h_RcwVr7tQaQJFuo6tBmA3kW_Oq1v9eA&oe=62531E9B&_nc_sid=7bff83', video_url='https://scontent-maa2-1.cdninstagram.com/v/t50.2886-16/10000000_675280210346049_2692931176807863221_n.mp4?_nc_ht=scontent-maa2-1.cdninstagram.com&_nc_cat=109&_nc_ohc=VzoUu4QEJ7AAX9h8pmT&edm=ABfd0MgBAAAA&ccb=7-4&oe=62532AE3&oh=00_AT_4dQ5gWwd7sk0SsmR3YtSILKSQ3URvYVLU_WoqYEvk5A&_nc_sid=7bff83', video_view_count=2257, post_source='https://scontent-maa2-1.cdninstagram.com/v/t50.2886-16/10000000_675280210346049_2692931176807863221_n.mp4?_nc_ht=scontent-maa2-1.cdninstagram.com&_nc_cat=109&_nc_ohc=VzoUu4QEJ7AAX9h8pmT&edm=ABfd0MgBAAAA&ccb=7-4&oe=62532AE3&oh=00_AT_4dQ5gWwd7sk0SsmR3YtSILKSQ3URvYVLU_WoqYEvk5A&_nc_sid=7bff83', taken_at_timestamp=datetime.datetime(2022, 4, 7, 0, 59, 30))
# Post(likes=91, comments=2, caption=None, is_video=True, timestamp=1646536096, location=None, shortcode='Cavyj7fDvDD', post_url='https://www.instagram.com/p/Cavyj7fDvDD/', display_url='https://scontent-maa2-2.cdninstagram.com/v/t51.2885-15/275179028_510054607204803_3937374329194849775_n.jpg?stp=dst-jpg_e15_fr_p1080x1080&_nc_ht=scontent-maa2-2.cdninstagram.com&_nc_cat=103&_nc_ohc=hgDvPd4iRJkAX80LW8Y&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT8C5p1TgKsQXHSmmnLHFrzPxqpAQSNKm9-M4ZIq5zBmNA&oe=6253ACC0&_nc_sid=7bff83', video_url='https://scontent-maa2-1.cdninstagram.com/v/t50.2886-16/275221401_353129270040318_5644548012723100557_n.mp4?_nc_ht=scontent-maa2-1.cdninstagram.com&_nc_cat=106&_nc_ohc=fmHX8eA_Rp4AX9a71pf&edm=ABfd0MgBAAAA&ccb=7-4&oe=6253A038&oh=00_AT-ucYEwl2WueqSdYO9tS_fKd2nQdWDOYbcLG1CfzPO5Ug&_nc_sid=7bff83', video_view_count=1087, post_source='https://scontent-maa2-1.cdninstagram.com/v/t50.2886-16/275221401_353129270040318_5644548012723100557_n.mp4?_nc_ht=scontent-maa2-1.cdninstagram.com&_nc_cat=106&_nc_ohc=fmHX8eA_Rp4AX9a71pf&edm=ABfd0MgBAAAA&ccb=7-4&oe=6253A038&oh=00_AT-ucYEwl2WueqSdYO9tS_fKd2nQdWDOYbcLG1CfzPO5Ug&_nc_sid=7bff83', taken_at_timestamp=datetime.datetime(
BJkYXNoX2Jhc2VsaW5lXzFfdjERAHX%2BBwA%3D&ccb=7-4&oe=62535C31&oh=00_AT9SvZvrZytiZfaZwaRD_11FECWBX9exucBmQMv1nU9K1g&_nc_sid=7bff83', taken_at_timestamp=datetime.datetime(2021, 12, 17, 19, 36, 59))

# %% [markdown]
# # Scrapping Naukari

# %%
# import the required libraries
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import requests

# %%
jobs -->  data-science, big-data, python-developer, data-analyst, dev-ops
location --> new-delhi, mumbai, banglore, chennai
# Out:
#   File "C:\Users\Vishal\AppData\Local\Temp\ipykernel_11820\2726191713.py", line 1
#     jobs -->  data-science, big-data, python-developer, data-analyst, dev-ops
#            ^
# SyntaxError: invalid syntax

# %%
job = input("Enter the job you want to apply for:").replace(' ', '')
location = input("Enter the location you want to apply for:").replace(' ','')
# Out:
# Enter the job you want to apply for:data science
# Enter the location you want to apply for:new delhi

# %%
# url to scrape
url = f"https://www.naukri.com/{job}-jobs-in-{location}"
print(url)
# Out:
# https://www.naukri.com/datascience-jobs-in-newdelhi

# %%
# requesting the page in HTML format
page = requests.get(url)

# %%
# getting the page
page.text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <meta http-equiv="X-UA-Compatible" content="IE=Edge" /> <meta name="viewport" content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> <link rel="dns-prefetch preconnect" href="//static.naukimg.com"> <link rel="dns-prefetch preconnect" href="//img.naukimg.com"> <link rel="dns-prefetch preconnect" href="//logs.naukri.com"> <link rel="dns-prefetch preconnect" href="//lg.naukri.com"> <link rel="dns-prefetch" href="https://www.googletagmanager.com" /> <base href="//www.naukri.com" /> <link rel="manifest" href="./manifest.json"> <link rel="preload" as="style" href="//static.naukimg.com/s/7/109/c/main.38449b98.min.css"/> <link rel="preload" as="script" href="//static.naukimg.com/s/7/109/j/main.5acbf5ba.min.js"> <script>\n        window.ipAddress = "www.naukri.com";\n        window.DEBUG = true;\n        window.appId = 135;\n                    var isCrawler = false;\n                            var ucBrowser = false;\n            </script>   <style type="text/css"> .splScrn{ height: 100%; } body{margin:0} .nkIcon { width: 19rem; height:19rem; margin: auto; position: relative; padding-top: 95px; } .nk-text { font-size: 40px; margin-bottom: 60px; text-align: center; font-weight: 700; color:#999; font-family:arial } #circleG { width: 9rem; margin: auto } .circleG { background-color: #2DABE2; float: left; height: 14px; margin: 5px; width: 14px; animation-name: bounce_circleG; -o-animation-name: bounce_circleG; -ms-animation-name: bounce_circleG; -webkit-animation-name: bounce_circleG; -moz-animation-name: bounce_circleG; animation-duration: 1.8s; -o-animation-duration: 1.8s; -ms-animation-duration: 1.8s; -webkit-animation-duration: 1.8s; -moz-animation-duration: 1.8s; animation-iteration-count: infinite; -o-animation-iteration-count: infinite; -ms-animation-iteration-count: infinite; -webkit-animation-iteration-count: infinite; -moz-animation-iteration-count: infinite; animation-direction: normal; -o-animation-direction: normal; -ms-animation-direction: normal; -webkit-animation-direction: normal; -moz-animation-direction: normal; border-radius: 50%; -o-border-radius: 50%; -ms-border-radius: 50%; -webkit-border-radius: 50%; -moz-border-radius: 50% } #root, body, html { height: 100% } #circleG_1 { animation-delay: .45s; -o-animation-delay: .45s; -ms-animation-delay: .45s; -webkit-animation-delay: .45s; -moz-animation-delay: .45s } #circleG_2 { animation-delay: .65s; -o-animation-delay: .65s; -ms-animation-delay: .65s; -webkit-animation-delay: .65s; -moz-animation-delay: .65s } #circleG_3 { animation-delay: .85s; -o-animation-delay: .85s; -ms-animation-delay: .85s; -webkit-animation-delay: .85s; -moz-animation-delay: .85s } #circleG_4 { animation-delay: 1.05s; -o-animation-delay: 1.05s; -ms-animation-delay: 1.05s; -webkit-animation-delay: 1.05s; -moz-animation-delay: 1.05s } #circleG_5 { animation-delay: 1.25s; -o-animation-delay: 1.25s; -ms-animation-delay: 1.25s; -webkit-animation-delay: 1.25s; -moz-animation-delay: 1.25s } @keyframes bounce_circleG { 50% { width: 10px; height: 10px; margin: 7px; background-color: rgba(12, 109, 182, 0) } } </style> </head> <body>  <noscript> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NX744H"height="0" width="0" style="display:none;visibility:hidden"></iframe> </noscript>  <div id="root"> <div class="splScrn"> <div class="row top"> <div class="nkIcon"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 315 315"><style type="text/css"> .st0{fill:#2DABE2;} .st1{fill:#0C6DB6;} .st2{fill:#EC2227;} .st3{fill:#444444;} .st4{fill-rule:evenodd;clip-rule:evenodd;fill:#EC2227;} .st5{fill-rule:evenodd;clip-rule:evenodd;fill:#0C6DB6;} </style><path class="st0" d="M0 200.8h10v4.6c1.5-1.9 3-3.2 4.5-4 1.5-0.8 3.4-1.2 5.6-1.2 3 0 5.3 0.9 7 2.7 1.7 1.8 2.5 4.5 2.5 8.2v17.8H18.8v-15.4c0-1.8-0.3-3-1-3.7 -0.7-0.7-1.6-1.1-2.7-1.1 -1.3 0-2.4 0.5-3.2 1.5 -0.8 1-1.2 2.8-1.2 5.3v13.4H0V200.8z"/><path class="st0" d="M45.8  ...

# %%
# Install driver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/100.0.4896.60/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Vishal\.wdm\drivers\chromedriver\win32\100.0.4896.60]
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source,"html.parser")
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Datascience Jobs In Newdelhi - 10655 Datascience Job Vacancies In Newdelhi - Naukri.com
#   </title>
#   <meta content="Apply To 10655 Datascience Jobs In Newdelhi On Naukri.com, India's No.1 Job Portal. Explore Datascience Job Openings In Newdelhi Now!" name="description"/>
#   <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/datascience-jobs-in-newdelhi" rel="alternate"/>
#   <link href="https://www.naukri.com/datascience-jobs-in-newdelhi" rel="canonical"/>
#   <meta content="jobsearch" name="atdlayout"/>
#   <meta content="ALL" name="robots"/>
#   <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>
#   <meta content="no-cache" name="pragma"/>
#   <meta content="general" name="rating"/>
#   <meta content="1 day" name="revisit-after"/>
#   <meta content="GLOBAL" name="distribution"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="www.naukri.com" name="author"/>
#   <meta content="EN" name="content-language"/>
#   <meta content="171330469593307" property="fb:app_id"/>
#   <meta content="2022 Naukri.com" name="copyright"/>
#   <meta content="https://static.naukimg.com/s/4/100/i/naukri_Logo.png" property="og:image"/>
#   <meta content="https://www.naukri.com/datascience-jobs-in-newdelhi" property="og:url"/>
#   <meta content="Naukri.com" property="og:site_name"/>
#   <meta content="Apply To 10655 Datascience Jobs In Newdelhi On Naukri.com, India's No.1 Job Portal. Explore Datascience Job Openings In Newdelhi Now!" property="og:description"/>
#   <meta content="Datascience Jobs In Newdelhi - 10655 Datascience Job Vacancies In Newdelhi - Naukri.com" property="og:title"/>
#   <link href="//static.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="//img.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="//logs.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="//lg.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <base href="//www.naukri.com"/>
#   <link href="./manifest.json" rel="manifest"/>
#   <link as="style" href="//static.naukimg.com/s/7/109/c/main.38449b98.min.css" rel="preload"/>
#   <link as="script" href="//static.naukimg.com/s/7/109/j/main.5acbf5ba.min.js" rel="preload"/>
#   <script async="" src="https://connect.facebook.net/signals/config/282225171957352?v=2.9.57&amp;r=stable">
#   </script>
#   <script defer="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NX744H">
#   </script>
#   <script>
#    window.ipAddress = "www.naukri.com";
#         window.DEBUG = true;
#         window.appId = 135;
#                     var isCrawler = false;
#                             var ucBrowser = false;
#   </script>
#   <style type="text/css">
#    .splScrn{ height: 100%; } body{margin:0} .nkIcon { width: 19rem; height:19rem; margin: auto; position: relative; padding-top: 95px; } .nk-text { font-size: 40px; margin-bottom: 60px; text-align: center; font-weight: 700; color:#999; font-family:arial } #circleG { width: 9rem; margin: auto } .circleG { background-color: #2DABE2; float: left; height: 14px; margin: 5px; width: 14px; animation-name: bounce_circleG; -o-animation-name: bounce_circleG; -ms-animation-name: bounce_circleG; -webkit-animation-name: bounce_circleG; -moz-animation-name: bounce_circleG; animation-duration: 1.8s; -o-animation-duration: 1.8s; -ms-animation-duration: 1.8s; -webkit-animation-duration: 1.8s; -moz-animation-duration: 1.8s; animation-iteration-count: infinite; -o-animation-iteration-count: infinite; -ms-animation-iteration-count: infinite; -webkit-animation-iteration-count: infinite; -moz-animation-iteration-count: infinite; animation-direction: normal; -o-animation-direction: normal; -ms-animation-direction: normal; -webkit-animation-direction: normal; -moz-animation-direction: normal; border-radius: 50%; -o-border-radius: 50%; -ms-border-radius: 50%; -webkit-border-radius: 50%; -moz-border-radius: 50% } #root, body, html { height: 100% } #circleG_1 { animation-delay: .45s; -o-animation-delay: .45s; -ms-animation-delay: .45s; -webkit-animation-delay: .45s; -moz-animation-delay: .45s } #circleG_2 { animation-delay: .65s; -o-animation-delay: .65s; -ms-animation-delay: .65s; -webkit-animation-delay: .65s; -moz-animation-delay: .65s } #circleG_3 { animation-delay: .85s; -o-animation-delay: .85s; -ms-animation-delay: .85s; -webkit-animation-delay: .85s; -moz-animation-delay: .85s } #circleG_4 { animation-delay: 1.05s; -o-animation-delay: 1.05s; -ms-animation-delay: 1.05s; -webkit-animation-delay: 1.05s; -moz-animation-delay: 1.05s } #circleG_5 { animation-delay: 1.25s; -o-animation-delay: 1.25s; -ms-animation-delay: 1.25s; -webkit-animation-delay: 1.25s; -moz-animation-delay: 1.25s } @keyframes bounce_circleG { 50% { width: 10px; height: 10px; margin: 7px; background-color: rgba(12, 109, 182, 0) } }
#   </style>
#   <script>
#    bazadebezolkohpepadr="132708587"
#   </script>
#   <script defer="" src="https://www.naukri.com/akam/13/7e8f97d" type="text/javascript">
#   </script>
#   <script async="" src="//static.naukri.com/s/0/1/j/ub_v1.13.min.js">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2022040701.js">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/971665778/?random=1649748214868&amp;cv=9&amp;fst=1649748214868&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=816&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=330&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wg460&amp;sendb=1&amp;ig=1&amp;data=dynx_pagetype%3Dsearchresults%3Bdynx_itemid%3D-%3Bevent%3Dgtm.js&amp;frm=0&amp;url=https%3A%2F%2Fwww.naukri.com%2Fdatascience-jobs-in-newdelhi&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion/1056982488/?random=1649748214869&amp;cv=9&amp;fst=1649748214869&amp;num=1&amp;value=0&amp;label=nnLpCKy315UBENiLgfgD&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=816&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=330&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wg460&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.naukri.com%2Fdatascience-jobs-in-newdelhi&amp;auid=1416692814.1649748215&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion/764936320/?random=1649748215501&amp;cv=9&amp;fst=1649748215501&amp;num=1&amp;value=0&amp;label=pPzLCK-cuKkDEICB4OwC&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=816&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=330&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wg460&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.naukri.com%2Fdatascience-jobs-in-newdelhi&amp;auid=1416692814.1649748215&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/vendors~Layout.b85484c4.min.js">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/Layout~companyPage~searchResult.29355e16.min.js">
#   </script>
#   <link crossorigin="anonymous" href="//static.naukimg.com/s/7/109/c/Layout~QuickSearchBand~searchResult.b3416188.min.css" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/Layout~QuickSearchBand~searchResult.d295be24.min.js">
#   </script>
#   <link crossorigin="anonymous" href="//static.naukimg.com/s/7/109/c/Layout~searchResult.9f494b3a.min.css" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/Layout~searchResult.f76d63d2.min.js">
#   </script>
#   <link crossorigin="anonymous" href="//static.naukimg.com/s/7/109/c/Layout.51cecadd.min.css" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/Layout.5dbeda70.min.js">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/searchResult.92a1c7b2.min.js">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/jquery.7814362b.min.js">
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.naukri.com","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.naukri.com/jobs-in-newdelhi","name":"Jobs in newdelhi"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.naukri.com/datascience-jobs","name":"datascience Jobs"}},{"@type":"ListItem","position":4,"item":{"name":"datascience Jobs In newdelhi"}}]}
#   </script>
#   <link crossorigin="anonymous" href="//static.naukimg.com/s/7/109/c/listing.68535671.min.css" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/listing.5ea9873d.min.js">
#   </script>
#   <script class="dfpScript">
#    googletag.cmd.push(function(){
#             googletag.destroySlots();
#             googletag.defineSlot('/1268732/Naukri_Display/naukri_srp_web_top_300x250', [[250,250],[300,250],[200,200],[180,150]], 'div-gpt-ad-1529415230769-0').addService(googletag.pubads());
#             googletag.defineSlot('/1268732/Naukri_Display/naukri_srp_web_middle_300x250_sticky', [[250,250],[200,200],[300,300],[300,250],[180,150]], 'div-gpt-ad-1529415230769-1').addService(googletag.pubads());
#
#         googletag.pubads().disableInitialLoad();
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
bangalore-bengaluru-delhi-ncr-mumbai-all-areas-0-to-5-years-280322004677","name":"Part Time || Data Science - Academic Content || Work from Home","image":"https://img.naukri.com/logo_images/v3/833688.gif"},{"@type":"ListItem","position":9,"url":"https://www.naukri.com/job-listings-sr-principal-quantitative-analytics-and-data-science-gartner-india-research-advisory-services-pvt-ltd-gurgaon-gurugram-5-to-9-years-060422500952","name":"Sr Principal, Quantitative Analytics and Data Science","image":"https://img.naukri.com/logo_images/v3/1932062.gif"},{"@type":"ListItem","position":10,"url":"https://www.naukri.com/job-listings-data-scientist-analyst-liquor-industry-new-delhi-omam-consultants-pvt-ltd-new-delhi-6-to-11-years-270322000003","name":"Data Scientist & Analyst - Liquor Industry, New Delhi"},{"@type":"ListItem","position":11,"url":"https://www.naukri.com/job-listings-data-scientist-jacobs-engineering-india-pvt-ltd-bangalore-bengaluru-delhi-ncr-mumbai-all-areas-3-to-5-years-050422008549","name":"Data Scientist","image":"https://img.naukri.com/logo_images/v3/74949.gif"},{"@type":"ListItem","position":12,"url":"https://www.naukri.com/job-listings-data-science-engineer-reliance-jio-infocomm-limited-hyderabad-secunderabad-gurgaon-gurugram-bangalore-bengaluru-mumbai-all-areas-2-to-6-years-060422003056","name":"Data Science Engineer"},{"@type":"ListItem","position":13,"url":"https://www.naukri.com/job-listings-data-science-exl-services-com-i-pvt-ltd-bangalore-bengaluru-delhi-ncr-3-to-8-years-050422008875","name ...
#   </script>
#   <link href="https://www.naukri.com/datascience-jobs-in-newdelhi-2" rel="next"/>
#   <link crossorigin="anonymous" href="//static.naukimg.com/s/7/109/c/tagsAndSkills.9e786355.min.css" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/tagsAndSkills.f29d3de0.min.js">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/dropdown.4bcba828.min.js">
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" src="//static.naukimg.com/s/7/109/j/4.ff20266b.min.js">
#   </script>
#   <style>
#    @font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu72xKOzY.woff2) format("woff2");unicode-range:U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu5mxKOzY.woff2) format("woff2");unicode-range:U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7mxKOzY.woff2) format("woff2");unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu4WxKOzY.woff2) format("woff2");unicode-range:U+0370-03FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7WxKOzY.woff2) format("woff2");unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7GxKOzY.woff2) format("woff2");unicode-range:U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local("Roboto"),local("Roboto-Regular"),url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu4mxK.woff2) format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fCRc4EsA.woff2) format("woff2");unicode-range:U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fABc4EsA.woff2) format("woff2");unicode-range:U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fCBc4EsA.woff2) format("woff2");unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fBxc4EsA.woff2) format("woff2");unicode-range:U+0370-03FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fCxc4EsA.woff2) format("woff2");unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fChc4EsA.woff2) format("woff2");unicode-range:U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local("Roboto Medium"),local("Roboto-Medium"),url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fBBc4.woff2) format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC,  ...
#   </style>
#   <style>
#    @font-face {
# 	font-family: "chatBotIcons";
# 	src: url("data:application/vnd.ms-fontobject;charset=utf-8;base64,...?#iefix") format("embedded-opentype"),
# url("data:application/font-woff;charset=utf-8;base64,...") format("woff"),
# url("data:font/woff2;charset=utf-8;base64,...") format("woff2"),
# url("data:application/x-font-ttf;charset=utf-8;base64,...") format("truetype");
# }
#
# .chatBot {
# 	line-height: 1;
# }
#
# .chatBot:before {
# 	font-family: chatBotIcons !important;
# 	font-style: normal;
# 	font-weight: normal !important;
# 	vertical-align: top;
# }
#
# .chatBot-add:before {
# 	content: "\f101";
# }
# .chatBot-ArrowDown:before {
# 	content: "\f102";
# }
# .chatBot-ArrowUp:before {
# 	content: "\f103";
# }
# .chatBot-Back:before {
# 	content: "\f104";
# }
# .chatBot-calendar:before {
# 	content: "\f105";
# }
# .chatBot-check_circle:before {
# 	content: "\f106";
# }
# .chatBot-check:before {
# 	content: "\f107";
# }
# .chatBot-clock:before {
# 	content: "\f108";
# }
# .chatBot-close:before {
# 	content: "\f109";
# }
# .chatBot-cross:before {
# 	content: "\f10a";
# }
# .chatBot-DownArrow:before {
# 	content: "\f10b";
# }
# .chatBot-edit_pencil_pwa:before {
# 	content: "\f10c";
# }
# .chatBot-edit_pencil:before {
# 	content: "\f10d";
# }
# .chatBot-error_small:before {
# 	content: "\f10e";
# }
# .chatBot-experience:before {
# 	content: "\f10f";
# }
# .chatBot-ic-bot:before {
# 	content: "\f110";
# }
# .chatBot-ic-chat:before {
# 	content: "\f111";
# }
# .chatBot-ic-cross:before {
# 	content: "\f112";
# }
# .chatBot-ic-mini:before {
# 	content: "\f113";
# }
# .chatBot-location:before {
# 	content: "\f114";
# }
# .chatBot-pencil:before {
# 	content: "\f115";
# }
# .chatBot-restart:before {
# 	content: "\f116";
# }
# .chatBot-rupee:before {
# 	content: "\f117";
# }
# .chatBot-Search:before {
# 	content: "\f118";
# }
# .chatBot-star:before {
# 	content: "\f119";
# }
# .chatBot-tick:before {
# 	content: "\f11a";
# }
#   </style>
#   <style>
#    .chatbot_cardItem{margin-left:-16px;margin-right:-16px}.chatbot_ListItem{margin-bottom:12px;max-width:85%}.chatbot_ListItem.botItem{align-self:flex-start}.chatbot_ListItem.userItem{display:flex;align-self:flex-end;margin-top:8px;margin-bottom:20px}.chatbot_ListItem.botChips{align-self:flex-start;width:100%}.chatbot_ListItem.botChips .chipMsg{display:flex;align-items:center;justify-content:center}.chatbot_ListItem.botChips .chipMessage{width:100%}.chatbot_ListItem .msg{word-break:break-word;font-weight:400;font-size:14px;color:#191B1F;line-height:1.5;letter-spacing:-0.2px}.chatbot_ListItem .msg a{color:#518CFF;text-decoration:none}.chatbot_ListItem .chatbot_msgWrapper{position:relative}.chatbot_ListItem .chatbot_Info{position:relative;z-index:10;margin:-10px 0 -5px 4px;font-size:10px;align-self:flex-end;color:#5C6C88;white-space:nowrap;float:right}.invisibleSpace{width:50px;display:inline-block;vertical-align:middle}.userMsg{background-color:#E4EFFC;padding:8px 7px 10px 9px;border-radius:8px 8px 2px 8px;position:relative}.botMsg{position:relative;padding:8px 7px 10px 9px;border-radius:8px 8px 8px 2px;background-color:#F5F5F5}.editMsg{cursor:pointer;font-size:16px;margin-left:6px;vertical-align:text-bottom;color:#518CFF}
#   </style>
#   <style>
#    .chatbot_Chip{display:flex;align-items:center;text-align:center;margin-right:8px;margin-bottom:8px;border:1px solid  #D4DFEF;color:#191B1F;font-size:12px;font-weight:400;cursor:pointer;background:#fff;padding:4px 10px;border-radius:20px;box-sizing:border-box}.chatbot_Chip.chatbot_Selected{transition-duration:0.3s;background:#EDF5FF;border:1px solid #CDE2FF;font-weight:500;color:#518CFF}.chatbot_Chip .chatBot{color:#4A90E2;margin-left:4px;font-size:10px;vertical-align:text-bottom}.chatbot_Chip .chatBot.chatBot-tick{font-size:10px}.chatbot_Chip.cursorDisabled{cursor:not-allowed}
#   </style>
#   <style>
#    .chatbot_Chips{display:flex}.chatbot_Chips.chatbot_ChipsInRow{flex-wrap:wrap;align-items:center;justify-content:center}.chatbot_Chips.chatbot_ChipsInCol{flex-direction:column;margin-bottom:8px}.chatbot_Chips.chatbot_ChipsInCol :last-child{margin-bottom:0px}
#   </style>
#   <style>
#    .chatbot_MessageContainer{flex-grow:1;overflow:auto;height:350px;-webkit-animation-duration:0.4s;animation-duration:0.4s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:linear;animation-timing-function:linear;background:#fff}@-webkit-keyframes chatbot_SlideUp{from{height:0;overflow:hidden}to{height:350px;overflow:auto}}@keyframes chatbot_SlideUp{from{height:0;overflow:hidden}to{height:350px;overflow:auto}}@-webkit-keyframes chatbot_SlideDown{from{overflow:hidden}to{height:0px}}@keyframes chatbot_SlideDown{from{overflow:hidden}to{height:0px}}.chatbot_MessageContainer .list{margin:0px 0 14px 0px;padding:0 16px;display:flex;flex-flow:column;list-style-type:none}.chatbot_MessageContainer .list li:last-child{margin-bottom:0px}.chatbot_MessageContainer.chatbot_Hide{-webkit-animation-name:chatbot_SlideDown;animation-name:chatbot_SlideDown;-webkit-animation-duration:0.4s;animation-duration:0.4s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:linear;animation-timing-function:linear;overflow:hidden;flex:none}.chatbot_MessageContainer .naukLogoMsg{background-size:cover;width:48px;height:48px;background-image:url(data:image/png;base64,...)}.hideBorder{border:none}.chatbot_MessageContainer::-webkit-scrollbar{width:4px}.chatbot_MessageContainer::-webkit-scrollbar-thumb{background-color:#DFE6ED;border-radius:2px;height:216px}.chatbot_MessageContainer::-webkit-scrollbar-track{background-color:#fff}
#   </style>
#   <style>
#    .chatbot_SendMessageContainer{display:flex;background:#fff;box-sizing:border-box;max-width:100%}.chatbot_SendMessageContainer .chatbot_InputContainer{background-color:#FBFBFB;border:1px solid #D4DFEF;max-width:calc(100% - 42px);border-radius:26px;display:flex;flex:1 1}.chatbot_SendMessageContainer .chatbot_InputContainer .textAreaWrapper{padding:10px 19px;position:relative;display:flex;flex:1 1;overflow:hidden;cursor:text}.chatbot_SendMessageContainer .chatbot_InputContainer .textAreaWrapper .textArea{position:relative;z-index:1;padding-right:2px;min-height:20px;max-height:100px;overflow-x:hidden;overflow-y:auto;word-wrap:break-word;white-space:pre-wrap;outline:none;-webkit-user-select:text;-moz-user-select:text;-ms-user-select:text;user-select:text;line-height:20px;border:none;resize:none;height:auto;font-family:inherit;margin-bottom:0px;background-color:#FBFBFB;font-size:14px;font-weight:400;color:#191B1F;box-sizing:border-box;flex:1 1}.chatbot_SendMessageContainer .chatbot_InputContainer .textAreaWrapper .textArea:empty:before{content:attr(data-placeholder);color:#999}.chatbot_SendMessageContainer .chatbot_InputContainer input::-webkit-inner-spin-button{-webkit-appearance:none;background-color:red}.chatbot_SendMessageContainer .sendMsg{position:absolute;left:50%;top:50%;transform:translate(-50%, -50%);background-size:cover;width:21px;height:21px;background-image:url(data:image/svg+xml;base64,...)}.chatbot_SendMessageContainer ::-moz-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer :-ms-input-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer ::-ms-input-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer ::placeholder{color:#C0C8D6}.chatbot_SendMessageContainer ::-webkit-input-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer ::-moz-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer :-ms-input-placeholder{color:#C0C8D6 !important}.chatbot_SendMessageContainer ::-ms-clear{display:none}.chatbot_SendMessageContainer ::-ms-reveal{display:none}.chatbot_SendMessageContainer :-moz-placeholder{color:#C0C8D6}.chatbot_SendMessageContainer .send{height:32px;width:32px;background-color:#518CFF;border-radius:22px;text-align:center;align-self:center;position:relative;flex-shrink:0;margin-left:10px;cursor:pointer}.chatbot_SendMessageContainer .send.disabled{cursor:not-allowed;background-color:#D4DFEF}.chatbot_Hide{visibility:hidden;-webkit-animation-name:chatbot_SlideDown;animation-name:chatbot_SlideDown;-webkit-animation-duration:0.4s;animation-duration:0.4s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:linear;animation-timing-function:linear;overflow:hidden}@-webkit-keyframes chatbot_SlideDown{from{overflow:hidden}to{height:0px}}@keyframes chatbot_SlideDown{from{overflow:hidden}to{height:0px}}.textArea::-webkit-scrollbar{width:4px !important;height:6px !important;background-color:#DFE6ED}.textArea::-webkit-scrollbar-thumb{background-color:#DFE6ED;border-radius:2px}.textArea::-webkit-scrollbar-track{background-color:#fff}
#   </style>
#   <style>
#    .footerWrapper{margin-top:4px;padding:12px 14px;box-shadow:0 -2px 4px 0 rgba(0,0,0,0.08);background:#fff}.footerWrapper .footerChips{display:flex;flex-direction:column;margin-bottom:12px;max-height:150px}.footerWrapper .footerChips .footerChipsList{max-height:130px;overflow-y:auto}.footerWrapper .footerChips .footerChipsList::-webkit-scrollbar{width:4px;height:60px}.footerWrapper .footerChips .footerChipsList::-webkit-scrollbar-thumb{height:60px;background:#DFE6ED;border-radius:2px}.footerWrapper .footerChips .footerChipsList::-webkit-scrollbar-track{background:#fff}.footerWrapper .footerInputBoxWrapper{position:relative}.chatbotMinimize{margin-right:2px;margin-bottom:2px;width:20px;height:20px;cursor:pointer;align-self:flex-end}.chatBot-ic-mini::before{color:#C9D2E0;font-size:20px;line-height:normal}
#   </style>
#   <style>
#    .chatbot_loadMoreContainer{position:relative;overflow:hidden}.chatbot_loadMoreContainer .chatbot_loadMoreContentWrapper{z-index:9;display:flex;flex-direction:column;height:100%;background:#fff;border-radius:8px 8px 0 0;box-shadow:0 -1px 4px 0 rgba(0,0,0,0.08)}.chatbot_loadMoreBody{display:block;background-color:#fff;flex:1 1 auto;overflow:auto}.chatbot_loadMoreBody .chatbot_loadMoreList{margin:0px;padding:0 0px;display:flex;flex-flow:column;list-style-type:none}.chatbot_loadMoreBody .chatbot_loadMoreList li:first-child{border-top:1px solid #d4dfef}.chatbot_loadMoreBody .chatbot_ListItem{text-align:center;min-height:42px;box-sizing:border-box;max-width:100%;cursor:pointer;word-break:break-word;padding:11px 7px 11px 7px;margin:0px;border-bottom:1px solid #ecf1f8;font-size:14px;font-weight:400;color:#191b1f}.chatbot_loadMoreBody .chatbot_ListItem .optionVal{vertical-align:middle}.chatbot_loadMoreBody .chatbot_ListItem.chatbot_Selected{transition:background-color 0.3s;background-color:#edf5ff;color:#518cff;font-weight:600}.chatbot_loadMoreBody ul .chatbot_IndsutryGroup:first-of-type{margin-top:0px}.chatbot_loadMoreBody .chatbot_IndsutryGroup{border-bottom:1px solid #ecf1f8;border-top:0px !important;margin-top:24px;display:block}.chatbot_loadMoreBody .chatbot_IndsutryGroup .industryGroup{display:inline-block;color:#5c6c88;font-size:12px;line-height:20px;text-align:left;font-weight:600;margin:0px 0px 4px 16px}.chatbot_loadMoreBody .chatbot_IndustryList{cursor:pointer}.chatbot_loadMoreBody .chatbot_IndustryList .chatbot_IndustryWrapper{border-bottom:1px solid #ecf1f8;text-transform:capitalize;min-height:44px;display:flex;flex-flow:column;justify-content:center;padding:2px 99px 2px 26px}.chatbot_loadMoreBody .chatbot_IndustryList .chatbot_IndustryWrapper .chatbot_Industry_heading{color:#191b1f;font-size:14px;line-height:20px;text-align:left;white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.chatbot_loadMoreBody .chatbot_IndustryList .chatbot_IndustryWrapper .chatbot_Industry_subHeading{color:#5c6c88;font-size:11px;text-align:left;margin-top:2px;white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.chatbot_loadMoreNav{padding:24px 15px 24px 16px;box-sizing:border-box}.chatbot_loadMoreNav .backButtonContainer{display:flex;cursor:pointer}.chatbot_loadMoreNav .backButtonContainer .chatBot{line-height:unset}.chatbot_loadMoreNav .backButtonContainer .backButton{margin-left:8px}.chatbot_loadMoreNav .chatBot-Back::before{font-weight:bold !important}.chatbot_loadMoreNav .doneSelection{cursor:pointer}.chatbot_loadMoreNav .chatbot_loadMoreInputContainer{display:flex;align-items:center;height:44px;padding:0px 15px;border:1px solid #e6f0f6;border-radius:8px;box-shadow:0 1px 1px 0 rgba(95,110,163,0.13);background-color:#ffffff;box-sizing:border-box}.chatbot_loadMoreNav .chatbot_loadMoreInputContainer .chatBot-search{margin-top:4px;width:16px;height:16px;color:#518cff}.chatbot_loadMoreNav .chatbot_loadMoreInputContainer .chatbot_loadMoreTextArea{border:none;resize:none;outline:none;font-size:14px;font-weight:400;color:#191b1f;margin-bottom:0px;box-sizing:border-box;flex:1 1}.chatbot_loadMoreNav .chatbotBackIcon{margin-top:10px;margin-right:16px;margin-bottom:16px;width:20px;height:20px;cursor:pointer}.chatbot_loadMoreNav .chatBot-Back::before{font-size:22px}.chatbot_loadMoreNav ::-moz-placeholder{color:#c1c9d7}.chatbot_loadMoreNav :-ms-input-placeholder{color:#c1c9d7}.chatbot_loadMoreNav ::-ms-input-placeholder{color:#c1c9d7}.chatbot_loadMoreNav ::placeholder{color:#c1c9d7}.chatbot_loadMoreNav ::-webkit-input-placeholder{color:#c1c9d7}.chatbot_loadMoreNav ::-moz-placeholder{color:#c1c9d7}.chatbot_loadMoreNav :-ms-input-placeholder{color:#c1c9d7 !important}.chatbot_loadMoreNav :-moz-placeholder{color:#c1c9d7}.chatbot_loadMoreBody::-webkit-scrollbar{background-color:#dfe6ed;width:4px}.chatbot_loadMoreBody::-webkit-scrollbar-thumb{background-color:#dfe6ed;border-radius:2px;height:216px}.chatbot_loadMoreBody::-webkit-scrollbar-track{back ...
#   </style>
#  </head>
#  <body style="padding-right: 0rem; overflow: hidden;">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NX744H" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="root">
#    <div class="headGNBWrap">
#     <div class="headGNB cloneCont wrap">
#      <a class="fl nLogo" href="https://www.naukri.com">
#       <img data-ga-track="Company Logo|Company Logo" src="https://static.naukri.com/s/4/100/i/naukri_Logo.png"/>
#      </a>
#      <ul class="midSec menu">
#       <li class="mActive">
#        <a data-ga-track="Main Navigation Jobs|Jobs Icon" href="https://www.naukri.com/browse-jobs" target="_blank" title="Search Jobs">
#         <span class="topIcon jobs">
#         </span>
#         <div class="mTxt">
#          Jobs
#         </div>
#        </a>
#        <div class="subMenu c2">
#         <ul class="group">
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Search Jobs" href="https://www.naukri.com" target="_blank" title="Search Jobs">
#            Search Jobs
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Create Free Job Alert" href="https://www.naukri.com/free-job-alerts" target="_blank" title="Create Free Job Alert">
#            Create Free Job Alert
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Register Now" href="https://www.naukri.com/registration/createAccount?othersrcp=16201&amp;err=1" target="_blank" title="Register Now">
#            Register Now
#           </a>
#          </li>
#         </ul>
#         <ul class="group">
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Jobs by Location" href="https://www.naukri.com/jobs-by-location" target="_blank" title="Jobs by Location">
#            Jobs by Location
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Jobs by Skill" href="https://www.naukri.com/top-skill-jobs" target="_blank" title="Jobs by Skill">
#            Jobs by Skill
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Jobs by Designation" href="https://www.naukri.com/top-jobs-by-designations" target="_blank" title="Jobs by Designation">
#            Jobs by Designation
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Jobs by Company" href="https://www.naukri.com/top-company-jobs" target="_blank" title="Jobs by Company">
#            Jobs by Company
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Jobs by Category" href="https://www.naukri.com/jobs-by-category" target="_blank" title="Jobs by Category">
#            Jobs by Category
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Jobs|Browse All Jobs" href="https://www.naukri.com/browse-jobs" target="_blank" title="Browse All Jobs">
#            Browse All Jobs
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li>
#        <a data-ga-track="Main Navigation Recruiters|Recruiters Icon" href="https://www.naukri.com/recruiters" target="_blank" title="Search Recruiters">
#         <span class="topIcon jobs Recr">
#         </span>
#         <div class="mTxt">
#          Recruiters
#         </div>
#        </a>
#        <div class="subMenu">
#         <ul>
#          <li>
#           <a data-ga-track="Main Navigation Recruiters|Browse all" href="https://www.naukri.com/recruiters/browse-all-recruiters" target="_blank" title="Browse All Recruiters">
#            Browse All Recruiters
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Recruiters|Recruiter Connection" href="https://resume.naukri.com/contact-recruiters-hr?fftid=GNB_RC" target="_blank" title="Recruiter Connection">
#            Recruiter Connection
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Recruiters|Goto Naukri Recruiter" href="https://naukrirecruiter.naukri.com?src=128" target="_blank" title="Go to NaukriRecruiter">
#            Go to NaukriRecruiter
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li>
#        <a data-ga-track="Main Navigation Companies|Companies Icon" href="https://www.naukri.com/top-company-jobs" target="_blank" title="Jobs Posted By Top Companies">
#         <span class="topIcon jobs Comp">
#         </span>
#         <div class="mTxt">
#          Companies
#         </div>
#        </a>
#        <div class="subMenu">
#         <ul>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Browse All Companies" href="https://www.naukri.com/top-company-jobs" target="_blank" title="Browse All Companies">
#            Browse All Companies
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|About Companies" href="https://www.ambitionbox.com/list-of-companies?utm_source=naukri&amp;utm_medium=gnb" rel="noindex nofollow" target="_blank" title="About Companies">
#            About Companies
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Interview Questions" href="https://www.ambitionbox.com/interviews?utm_source=naukri&amp;utm_medium=gnb" target="_blank" title="Interview Questions">
#            Interview Questions
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Write Company Review" href="https://www.ambitionbox.com/contribute/company-review?utm_source=naukri&amp;utm_medium=gnb" rel="noindex nofollow" target="_blank" title="Write Company Review">
#            Write Company Review
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Share Interview Questions" href="https://www.ambitionbox.com/contribute/interview-story?utm_source=naukri&amp;utm_medium=gnb" target="_blank" title="Write Interview Advice">
#            Write Interview Advice
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Company Reviews" href="https://www.ambitionbox.com/reviews?utm_source=naukri&amp;utm_medium=gnb" target="_blank" title="Company Reviews">
#            Company Reviews
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Companies|Company Salaries" href="https://www.ambitionbox.com/salaries?utm_source=naukri&amp;utm_medium=desktop&amp;utm_campaign=gnb" target="_blank" title="Company Salaries">
#            Company Salaries
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li>
#        <a data-ga-track="Main Navigation Insights|Insights Icon" href="https://insights.naukri.com/careertools" target="_blank">
#         <span class="topIcon jobs Insights">
#         </span>
#         <div class="mTxt">
#          Tools
#         </div>
#        </a>
#        <div class="subMenu">
#         <ul>
#          <li>
#           <a data-ga-track="Main Navigation Insights|Career Dashboard" href="https://insights.naukri.com/careertools" target="_blank" title="Career Dashboard">
#            Career Dashboard
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Insights|Your next career move" href="https://insights.naukri.com/careertools/careerRole/" target="_blank" title="Your next career move">
#            Your next career move
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Insights|Skills Trends" href="https://insights.naukri.com/careertools/industrytrends" target="_blank" title="Skills Trends">
#            Skills Trends
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Insights|Naukri Lab" href="https://insights.naukri.com/careertools/naukriLab" target="_blank" title="Naukri Lab">
#            Naukri Lab
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li>
#        <a data-ga-track="Main Navigation Services|Services Icon" href="https://resume.naukri.com/resume-services?fftid=100001&amp;id=" target="_blank" title="Naukri FastForward- Resume Services">
#         <span class="topIcon jobs Serv">
#         </span>
#         <div class="mTxt">
#          Services
#         </div>
#        </a>
#        <div class="subMenu c3">
#         <ul class="group">
#          <li class="header1">
#           <a title="Resume Writing">
#            Resume Writing
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Text Resume" href="https://resume.naukri.com/resume-writing-services?fftid=101001" target="_blank" title="Text Resume">
#            Text Resume
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Visual Resume" href="https://resume.naukri.com/visual-resume-writing-services?fftid=101002" target="_blank" title="Visual Resume">
#            Visual Resume
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Resume Quality Score" href="https://resume.naukri.com/resume-quality-score?fftid=101003" target="_blank" title="Resume Quality Score - Free">
#            Resume Quality Score - Free
#           </a>
#          </li>
#          <li class="lastSib">
#           <a data-ga-track="Main Navigation Services|Resme Smaples" href="https://resume.naukri.com/resume-samples?fftid=101004" target="_blank" title="Resume Samples">
#            Resume Samples
#           </a>
#          </li>
#          <li class="header1">
#           <a data-ga-track="Main Navigation Services|Jobs4U" title="Jobs For You">
#            Jobs For You
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Jobs4U" href="https://resume.naukri.com/job-alerts-on-mobile-mail?fftid=101011#jobmail" target="_blank" title="Jobs4U">
#            Jobs4U
#           </a>
#          </li>
#         </ul>
#         <ul class="group">
#          <li class="header1">
#           <a>
#            Recruiter Reach
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Resume Display" href="https://resume.naukri.com/resume-display?fftid=101009" target="_blank" title="Resume Display">
#            Resume Display
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Priority Applicant" href="https://resume.naukri.com/priority-job-application?fftid=101019" target="_blank" title="Priority Applicant">
#            <span class="newStatus">
#            </span>
#            Priority Applicant
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|RecruiterConnection" href="https://resume.naukri.com/contact-recruiters-hr?fftid=101010" target="_blank" title="RecruiterConnection">
#            <span class="newStatus">
#            </span>
#            RecruiterConnection
#           </a>
#          </li>
#          <li class="lastSib">
#           <a data-ga-track="Main Navigation Services|Job Search Booster" href="https://resume.naukri.com/jobsearch-booster?fftid=101020" target="_blank" title="Job Search Booster">
#            Job Search Booster
#           </a>
#          </li>
#          <li class="header1">
#           <a>
#            Other
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Help" href="https://resume.naukri.com/frequently-asked-questions-faq/?fftid=101013" target="_blank" title="Help/FAQ">
#            Help / FAQ
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Career Advice" href="https://resume.naukri.com/articles/?fftid=101014" target="_blank" title="Career Advice">
#            Career Advice
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Contact Us" href="https://resume.naukri.com/contact-us?fftid=101015" target="_blank" title="Contact Us">
#            Contact Us
#           </a>
#          </li>
#          <li class="header1">
#           <a>
#            Monthly Subscriptions
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Basic &amp; Premium Plans" href="https://resume.naukri.com/subscription-product?fftid=101025" target="_blank" title="Basic &amp; Premium Plans">
#            Basic &amp; Premium Plans
#           </a>
#          </li>
#         </ul>
#         <ul class="group">
#          <li class="header1">
#           <a>
#            Courses / Certifications
#           </a>
#          </li>
#          <li>
#           <a data-ga-track="Main Navigation Services|Data Science" href="https://www.naukri.com/learning/data-science-courses-certification-training-ct123?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Data Science">
#            Data Science
#           </a>
#          </li>
#          <li>
# ...
#           </a>
#          </li>
#          <li class="item" style="left: 1280px;">
#           <a class="zomato" href="https://www.zomato.com" rel="nofollow" target="_blank" title="Zomato.com">
#           </a>
#          </li>
#          <li class="item" style="left: 1440px;">
#           <a class="meritnation" href="https://www.meritnation.com/" rel="nofollow" target="_blank" title="Meritnation.com">
#           </a>
#          </li>
#          <li class="item" style="left: 1600px;">
#           <a class="mydala" href="https://www.mydala.com/" rel="nofollow" target="_blank" title="Mydala.com">
#          <li class="item" style="left: 4800px;">
#           <a class="shiksha" href="https://www.shiksha.com/" target="_blank" title="Shiksha.com">
#           </a>
#          </li>
#          <li class="item" style="left: 4960px;">
#           <a class="policyBazaar" href="https://www.policybazaar.com/" rel="nofollow" target="_blank" title="PolicyBazaar.com">
#           </a>
#          </li>
#          <li class="item" style="left: 5120px;">
#           <a class="zomato" href="https://www.zomato.com" rel="nofollow" target="_blank" title="Zomato.com">
#           </a>
#          </li>
#          <li class="item" style="left: 5280px;">
#           <a class="meritnation" href="https://www.meritnation.com/" rel="nofollow" target="_blank" title="Meritnation.com">
#           </a>
#          </li>
#          <li class="item" style="left: 5440px;">
#           <a class="mydala" href="https://www.mydala.com/" rel="nofollow" target="_blank" title="Mydala.com">
#           </a>
#          </li>
#          <li class="item" style="left: 5600px;">
#           <a class="paisaBazaar" href="https://www.paisabazaar.com/" rel="nofollow" target="_blank" title="PaisaBazaar.com">
#           </a>
#          </li>
#         </ul>
#        </div>
#        <span class="arrowCont next">
#         <em class="arrow">
#         </em>
#        </span>
#       </div>
#      </div>
#     </div>
#     <div class="footer disclaimer">
#      <div class="wrap" style="text-align:center;">
#       All rights reserved @ 2022 Info Edge (India) Ltd.
#      </div>
#     </div>
#    </div>
#   </div>
#   <link href="//static.naukimg.com/s/7/109/c/main.38449b98.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <script id="ubScript">
#    (function() { var queuedSuperProps = []; var queuedEvents = []; window.ub = { track: function(eventName, eventProps) { queuedEvents.push([eventName, eventProps]) }, register: function(properties) { queuedSuperProps.push(properties); } };
#             var script = document.createElement("script"); script.async = true;script.trackTdsCookie=true,script.fingerprint=false,script.src = "//static.naukri.com/s/0/1/j/ub_v1.13.min.js";script.onload = function() { ub.init({
#                    trackTdsCookie : true, beaconUrl : "https://logs.naukri.com/uba", bulkBeaconUrl : "https://logs.naukri.com/collectorapi/v1/uba/bulk", queuedEvents:queuedEvents, queuedSuperProps:queuedSuperProps,  tenantId:'1' ,   subclientTenantId:'0' , autoTrack:false, blackList:
#                 []
#             }); };document.head.appendChild(script);}()); ub.register({ appId:109, pageName: "jobsearch",  tenantId:'1' ,  subclientTenantId:'0' , });
#   </script>
#   <script>
#    //hack of IE and safari bug : Super expression must either be null or a function, not undefined
#     if (typeof HTMLElement !== 'function') {
#         var _HTMLElement = function() {};
#         _HTMLElement.prototype = HTMLElement.prototype;
#         HTMLElement = _HTMLElement;
#     }
#   </script>
#   <script defer="" src="//static.naukimg.com/s/7/109/j/vendors~main.a3b7b539.min.js" type="text/javascript">
#   </script>
#   <script defer="" src="//static.naukimg.com/s/7/109/j/main.5acbf5ba.min.js" type="text/javascript">
#   </script>
#   <script src="//static.naukimg.com/s/0/0/j/nLoggerJB_v3.0.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.nLogger && nLogger.init({ "tag": "revamped_srp", "nLogger": { "beaconUrl": "https:\/\/lg.naukri.com\/uba", "eventName": "newMonkError", "deviceType": "SERVER" }, "boomerang": { "logBW": false, "beaconUrl": "https:\/\/lg.naukri.com\/uba", "imageURL": "\/\/static.naukimg.com\/s\/0\/0\/i\/", "eventName": "newMonkPerformance", "deviceType": "SERVER" }, "tenantId": 1, "appId": 109, "userIP": "2045974146" });
#   </script>
#   <script type="text/javascript">
#    (function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(),
#             event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s),
#             dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.defer = 'defer';
#         j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-NX744H');
#   </script>
#   <script defer="" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#   </script>
#   <noscript>
#    <img src="https://www.naukri.com/akam/13/pixel_7e8f97d?a=dD1hNTYwNDRiOWYyMzUwODBlMGFkMWU5NDU3YzNhMWRkNWYwMDRiMjkwJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#   <script src="/BuX8JgCG/x372VDH/fqNzC-P/T9/m3DErJfNb3zu/RiwSbRYqUQ/VB/1HYhJgJGA" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    (function(){try{window.setTimeout(function(){dataLayer.push({event:"fbAfterLoad"})},2E3)}catch(a){}})();
#   </script>
#   <iframe src="https://9911aef7c4c35eb97b24683bb7cfdbf6.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;">
#   </iframe>
#   <iframe height="0" src="https://www.google.com/recaptcha/api2/aframe" style="display: none;" width="0">
#   </iframe>
#   <script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    !function(a,c,f,g,b,d,e){a.fbq||(b=a.fbq=function(){b.callMethod?b.callMethod.apply(b,arguments):b.queue.push(arguments)},a._fbq||(a._fbq=b),b.push=b,b.loaded=!0,b.version="2.0",b.queue=[],d=c.createElement(f),d.defer=!0,d.src=g,e=c.getElementsByTagName(f)[0],e.parentNode.insertBefore(d,e))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","282225171957352");fbq("set","agent","tmgoogletagmanager","282225171957352");fbq("track","PageView");
# function triggerEvents(){for(var a in fbPixel)if(fbPixel[a]&&("[object Array]"===Object.prototype.toString.call(fbPixel[a])||"[object Object]"===Object.prototype.toString.call(fbPixel[a])))fbq("trackCustom",a,fbPixel[a]);else if(fbPixel[a]){var c={};c.value=fbPixel[a];fbq("trackCustom",a,c)}}
# if(window.fbPixel)triggerEvents();else var trackCustomEventsCount=0,myVar=setInterval(function(){trackCustomEventsCount++;window.fbPixel&&(clearInterval(myVar),triggerEvents());10<trackCustomEventsCount&&clearInterval(myVar)},1E3);
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=282225171957352&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script defer="" src="//static.naukimg.com/s/7/109/libs/depGNB_v2.min.js">
#   </script>
#   <script defer="" src="//static.naukimg.com/s/7/109/libs/depFooter_v1.min.js">
#   </script>
#   <script id="" type="text/javascript">
#    window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:google_tag_manager["GTM-NX744H"].macro(27)},{event:"setEmail",email:google_tag_manager["GTM-NX744H"].macro(28)},{event:"setSiteType",type:google_tag_manager["GTM-NX744H"].macro(29)},{event:"viewList",tms:"gtm-criteo-2.0.0",user_loggedin_status:google_tag_manager["GTM-NX744H"].macro(30),item:google_tag_manager["GTM-NX744H"].macro(31)||google_tag_manager["GTM-NX744H"].macro(32)});
#   </script>
#   <div id="criteo-tags-div" style="display: none;">
#    <iframe frameborder="0" height="0" id="criteo-syncframe-onetag" src='https://gum.criteo.com/syncframe?topUrl=www.naukri.com&amp;origin=onetag#{"bundle":{"origin":0,"value":null},"cw":true,"optout":{"origin":0,"value":null},"origin":"onetag","pm":0,"sid":{"origin":0,"value":null},"tld":"naukri.com","topUrl":"www.naukri.com","version":"5_9_0","ifa":{"origin":0,"value":null},"lsw":true}' style="border-width:0px; margin:0px; display:none" title="Criteo GUM iframe" width="0">
#    </iframe>
#    <script async="true" src="https://sslwidget.criteo.com/event?a=57144&amp;v=5.9.0&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dd&amp;p2=e%3Dvl%26tms%3Dgtm-criteo-2.0.0%26user_loggedin_status%3Dfalse%26p%3D%255B040122009836%252C110422010083%252C070422000310%252C300322904597%252C161221501679%252C180222002708%252C070422907893%252C280322004677%252C060422500952%252C270322000003%252C050422008549%252C060422003056%252C050422008875%252C300322902445%252C290322011462%252C180921004092%252C160721005471%252C060422908970%252C070421500217%252C290322010550%255D&amp;p3=e%3Ddis&amp;adce=1&amp;tld=naukri.com&amp;fu=https%3A%2F%2Fwww.naukri.com%2Fdatascience-jobs-in-newdelhi&amp;dtycbr=84835" type="text/javascript">
#    </script>
#   </div>
#   <div class="_chatBotContainer" id="_eoesfrpwcChatbotContainer">
#    <div class="chatbot_Drawer chatbot_right" id="_eoesfrpwcDrawer">
#     <div class="chatbot_DrawerContentWrapper">
#      <div class="chatbot_Nav" id="_eoesfrpwcNavbar">
#       <div class="crossIcon chatBot chatBot-ic-cross" style="margin-left:8px">
#       </div>
#      </div>
#      <div class="chatbot_MessageContainer" id="_eoesfrpwcMessages">
#       <ul class="list" id="chatList__eoesfrpwcMessages">
#        <li class="botLogo chatbot_ListItem">
#         <div class="chipMsg">
#          <span>
#           <div class="naukLogoMsg">
#           </div>
#          </span>
#         </div>
#        </li>
#        <li class="botItem chatbot_ListItem">
#         <div class="botMsg msg">
#          <div>
#           <span>
#            Hi! I am Naukri’s smart job search assistant!
#           </span>
#           <span class="invisibleSpace">
#           </span>
#          </div>
#          <div class="chatbot_Info">
#           12:53 pm
#          </div>
#         </div>
#        </li>
#        <li class="botItem chatbot_ListItem">
#         <div class="botMsg msg">
#          <div>
#           <span>
#            I see that you are looking for  jobs. New jobs are posted on Naukri every day.
#           </span>
#           <span class="invisibleSpace">
#           </span>
#          </div>
#          <div class="chatbot_Info">
#           12:53 pm
#          </div>
#         </div>
#        </li>
#        <li class="botItem chatbot_ListItem">
#         <div class="botMsg msg">
#          <div>
#           <span>
#            Please click on register and create an account to get the most out of Naukri!
#           </span>
#           <span class="invisibleSpace">
#           </span>
#          </div>
#          <div class="chatbot_Info">
#           12:53 pm
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <div class="footerWrapper" id="_eoesfrpwcFooter">
#       <div class="footerChips" id="_eoesfrpwcFooter_footerChips">
#        <div class="footerChipsList">
#         <div class="chatbot_Chips chatbot_ChipsInRow" id="_eoesfrpwcChips">
#          <div class="chatbot_Chip chipInRow chipItem" id="_eoesfrpwc6">
#           <span>
#            Register Now
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="footerInputBoxWrapper">
#        <div class="chatbot_SendMessageContainer" id="_eoesfrpwcInputBox">
#         <div class="chatbot_InputContainer">
#          <div class="textAreaWrapper">
#           <div class="textArea" contenteditable="true" data-placeholder="Type message here..." id="userInput__eoesfrpwcInputBox">
#           </div>
#          </div>
#         </div>
#         <div class="send disabled" id="sendMsg__eoesfrpwcInputBox">
#          <div class="sendMsg">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="chatbot_loadMore" id="_eoesfrpwcLoadMoreLayer">
#      </div>
#      <form>
#       <input accept="" class="chatbot_Uploader" id="_eoesfrpwcUploader" type="file"/>
#      </form>
#     </div>
#     <div class="chatbot_Overlay show" id="_eoesfrpwc2">
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
df = pd.DataFrame(columns=['Title','Company','Ratings','Reviews','URL'])

# %%
results = soup.find(class_='list')
results
# Out:
# <div class="list"><article class="jobTuple bgWhite br4 mb-8" data-job-id="040122009836"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-data-scientist-qualfon-advanced-technology-center-llp-mumbai-bangalore-bengaluru-delhi-ncr-6-to-10-years-040122009836?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=1&amp;px=1" target="_blank" title="Data Scientist">Data Scientist</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/qualfon-advanced-technology-center-jobs-careers-6045312" target="_blank" title="Qualfon Advanced Technology Center LLP">Qualfon Advanced Technology Center LLP</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.5<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/qualfon-advanced-technology-center-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(2 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="6-10 Yrs ">6-10 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Mumbai, Bangalore/Bengaluru, Delhi / NCR ">Mumbai, Bangalore/Bengaluru, Delhi / NCR</span></li></ul></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Bachelors degree (required) in Statistics, Mathematics, Computer Science, Engineering, ...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Six Sigma</li><li class="fleft fs12 grey-text lh16 dot">Advanced Analytics</li><li class="fleft fs12 grey-text lh16 dot">Statistics</li><li class="fleft fs12 grey-text lh16 dot">IT Skills</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">Testing</li><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft green"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">1 Day Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article><article class="jobTuple bgWhite br4 mb-8" data-job-id="110422010083"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-opening-for-data-scientist-rapid-miner-wipro-limited-kochi-cochin-kolkata-gurgaon-gurugram-chennai-coimbatore-bangalore-bengaluru-mumbai-all-areas-pune-hyderabad-6-to-11-years-110422010083?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=2&amp;px=1" target="_blank" title="Job Opening For Data Scientist - Rapid Miner">Job Opening For Data Scientist - Rapid Miner</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/wipro-jobs-careers-53141" target="_blank" title="Wipro">Wipro</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.9<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/wipro-reviews?utm_campaign ...

# %%
job_elems = results.find_all('article', class_="jobTuple bgWhite br4 mb-8")
job_elems
# Out:
# [<article class="jobTuple bgWhite br4 mb-8" data-job-id="040122009836"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-data-scientist-qualfon-advanced-technology-center-llp-mumbai-bangalore-bengaluru-delhi-ncr-6-to-10-years-040122009836?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=1&amp;px=1" target="_blank" title="Data Scientist">Data Scientist</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/qualfon-advanced-technology-center-jobs-careers-6045312" target="_blank" title="Qualfon Advanced Technology Center LLP">Qualfon Advanced Technology Center LLP</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.5<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/qualfon-advanced-technology-center-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(2 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="6-10 Yrs ">6-10 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Mumbai, Bangalore/Bengaluru, Delhi / NCR ">Mumbai, Bangalore/Bengaluru, Delhi / NCR</span></li></ul></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Bachelors degree (required) in Statistics, Mathematics, Computer Science, Engineering, ...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Six Sigma</li><li class="fleft fs12 grey-text lh16 dot">Advanced Analytics</li><li class="fleft fs12 grey-text lh16 dot">Statistics</li><li class="fleft fs12 grey-text lh16 dot">IT Skills</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">Testing</li><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft green"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">1 Day Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="110422010083"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-opening-for-data-scientist-rapid-miner-wipro-limited-kochi-cochin-kolkata-gurgaon-gurugram-chennai-coimbatore-bangalore-bengaluru-mumbai-all-areas-pune-hyderabad-6-to-11-years-110422010083?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=2&amp;px=1" target="_blank" title="Job Opening For Data Scientist - Rapid Miner">Job Opening For Data Scientist - Rapid Miner</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/wipro-jobs-careers-53141" target="_blank" title="Wipro">Wipro</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.9<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/wipro-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(19981 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="6-11 Yrs ">6-11 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="
src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=5&amp;px=1" target="_blank" title="Data Science - Senior Data Scientist">Data Science - Senior Data Scientist</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/paytm-jobs-careers-198177" target="_blank" title="Paytm">Paytm</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.7<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/paytm-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(3494 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="2-4 Yrs ">2-4 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Noida, Bangalore/Bengaluru ">Noida, Bangalore/Bengaluru</span></li></ul></div><div class="imgCont fright"><div class="lazyload-placeholder"></div></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Experience in data mining Proven experience as a Data Scientist or Data Analyst Experie...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Business Intelligence</li><li class="fleft fs12 grey-text lh16 dot">R</li><li class="fleft fs12 grey-text lh16 dot">Data Scientist</li><li class="fleft fs12 grey-text lh16 dot">C + +</li><li class="fleft fs12 grey-text lh16 dot">Hadoop</li><li class="fleft fs12 grey-text lh16 dot">Data Mining</li><li class="fleft fs12 grey-text lh16 dot">Data Visualization</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-premium"></i><span class="fleft fw500">PREMIUM</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">30+ Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="180222002708"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-hiring-for-data-science-intern-flip-robo-technologies-private-limited-noida-bangalore-bengaluru-0-to-1-years-180222002708?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=6&amp;px=1" target="_blank" title="Hiring For Data Science Intern">Hiring For Data Science Intern</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/data-trained-education-jobs-careers-5691152" target="_blank" title="FLIP ROBO TECHNOLOGIES PRIVATE LIMITED ">FLIP ROBO TECHNOLOGIES PRIVATE LIMITED </a><span class="starRating fleft dot" title="Powered by Ambition Box">4.4<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/flip-robo-technologies-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(14 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="0-1 Yrs ">0-1 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Noida, Bangalore/Bengaluru ">Noida, Bangalore/Bengaluru</span></li></ul></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Need to be a graduate with good knowledge of Data ScienceMust have excellent communicat...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Natural Language Processing</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li><li class="fleft fs12 grey-text lh16 dot">Deep Learning</li><li class="fleft fs12 grey-text lh16 dot">Python</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">4 Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="070422907893"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-data-scientist-python-sql-ave-promagne-noida-kota-mumbai-chandigarh-lucknow-agra-gurgaon-gurugram-jaipur-bangalore-bengaluru-3-to-8-years-070422907893?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=7&amp;px=1" target="_blank" title="Data Scientist - Python/SQL">Data Scientist - Python/SQL</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/premium-jobs-jobs-careers-678662" target="_blank" title="AVE-Promagne">AVE-Promagne</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="3-8 Yrs ">3-8 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Noida, Kota, Mumbai, Chandigarh, Lucknow, Agra, Gurgaon/Gurugram, Jaipur, Bangalore/Bengaluru ">Noida, Kota, Mumbai, Chandigarh, Lucknow, Agra, Gurgaon/Gurugram, Jaipur, Bangalore/Bengaluru</span></li></ul></div><div class="imgCont fright"><div class="lazyload-placeholder"></div></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Experience creating and using advanced machine learning algorithms and statistics: regr...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">SQL</li><li class="fleft fs12 grey-text lh16 dot">R</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">IT Skills</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li><li class="fleft fs12 grey-text lh16 dot">data analysis</li><li class="fleft fs12 grey-text lh16 dot">Logistic Regression</li><li class="fleft fs12 grey-text lh16 dot">predictive analytics</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">4 Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="280322004677"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-part-time-data-science-academic-content-work-from-home-evelyn-learning-systems-pvt-ltd-kolkata-mumbai-hyderabad-secunderabad-pune-ahmedabad-chennai-bangalore-bengaluru-delhi-ncr-mumbai-all-areas-0-to-5-years-280322004677?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=8&amp;px=1" target="_blank" title="Part Time || Data Science - Academic Content || Work from Home">Part Time || Data Science - Academic Content || Work from Home</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/evelyn-learning-systems-jobs-careers-833688" target="_blank" title="Evelyn Learning Systems">Evelyn Learning Systems</a><span class="starRating fleft dot" title="Powered by Ambition Box">3
a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="5-8 Yrs ">5-8 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Hyderabad/Secunderabad, Pune, Chennai, Gurgaon/Gurugram, Bangalore/Bengaluru ">Hyderabad/Secunderabad, Pune, Chennai, Gurgaon/Gurugram, Bangalore/Bengaluru</span></li></ul></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Good power point presentation skills and excellent team player</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">MySQL</li><li class="fleft fs12 grey-text lh16 dot">Data Management</li><li class="fleft fs12 grey-text lh16 dot">Statistical Modeling</li><li class="fleft fs12 grey-text lh16 dot">Algorithm</li><li class="fleft fs12 grey-text lh16 dot">SQL</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">5 Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="070421500217"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-gamma-lead-data-scientist-boston-consulting-group-mumbai-delhi-chennai-bengaluru-bangalore-7-to-12-years-070421500217?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=19&amp;px=1" target="_blank" title="GAMMA Lead Data Scientist">GAMMA Lead Data Scientist</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/boston-consulting-group-jobs-careers-487905" target="_blank" title="Boston Consulting Group">Boston Consulting Group</a><span class="starRating fleft dot" title="Powered by Ambition Box">4.0<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/bcg-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(82 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="7-12 Yrs ">7-12 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Mumbai, Delhi, Chennai, Bengaluru ">Mumbai, Delhi, Chennai, Bengaluru</span></li></ul></div><div class="imgCont fright"><div class="lazyload-placeholder"></div></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Practice Area Profile BCG GAMMA combines innovative skills in computer science, artific...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Data analysis</li><li class="fleft fs12 grey-text lh16 dot">Operations research</li><li class="fleft fs12 grey-text lh16 dot">data science</li><li class="fleft fs12 grey-text lh16 dot">Data management</li><li class="fleft fs12 grey-text lh16 dot">Business analytics</li><li class="fleft fs12 grey-text lh16 dot">Consulting</li><li class="fleft fs12 grey-text lh16 dot">Management consulting</li><li class="fleft fs12 grey-text lh16 dot">Business strategy</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-premium"></i><span class="fleft fw500">PREMIUM</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">30+ Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>,
#  <article class="jobTuple bgWhite br4 mb-8" data-job-id="290322010550"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-opening-for-data-scientist-rapid-miner-wipro-limited-kochi-cochin-kolkata-gurgaon-gurugram-chennai-coimbatore-bangalore-bengaluru-mumbai-all-areas-pune-hyderabad-7-to-12-years-290322010550?src=jobsearchDesk&amp;sid=16497482159814147&amp;xp=20&amp;px=1" target="_blank" title="Job Opening For Data Scientist - Rapid Miner">Job Opening For Data Scientist - Rapid Miner</a><div class="mt-7 companyInfo subheading lh16"><a class="subTitle ellipsis fleft" href="https://www.naukri.com/wipro-jobs-careers-53141" target="_blank" title="Wipro">Wipro</a><span class="starRating fleft dot" title="Powered by Ambition Box">3.9<i class="naukicon naukicon-saved ml-5 fright"></i></span><a class="reviewsCount ml-5 fleft blue-text" href="https://www.ambitionbox.com/reviews/wipro-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box">(19981 Reviews)</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span class="ellipsis fleft fs12 lh16" title="7-12 Yrs ">7-12 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span class="ellipsis fleft fs12 lh16" title="Not disclosed ">Not disclosed</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span class="ellipsis fleft fs12 lh16" title="Kochi/Cochin, Kolkata, Gurgaon/Gurugram, Chennai, Coimbatore, Bangalore/Bengaluru, Mumbai (All Areas), Pune, Hyderabad ">Kochi/Cochin, Kolkata, Gurgaon/Gurugram, Chennai, Coimbatore, Bangalore/Bengaluru, Mumbai (All Areas), Pune, Hyderabad</span></li></ul></div><div class="imgCont fright"><div class="lazyload-placeholder"></div></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Preferred Location is Experience in Architecting cloud native scalable AI platform</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Rapid Miner</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">SAS</li><li class="fleft fs12 grey-text lh16 dot">R</li><li class="fleft fs12 grey-text lh16 dot">SQL</li><li class="fleft fs12 grey-text lh16 dot">RapidMiner</li><li class="fleft fs12 grey-text lh16 dot">Microservices</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-premium"></i><span class="fleft fw500">PREMIUM</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">13 Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>]

# %%
# Company Name
for job_elem in job_elems:
    Company = job_elem.find('a',class_='subTitle ellipsis fleft')
    print(Company)
# Out:
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/qualfon-advanced-technology-center-jobs-careers-6045312" target="_blank" title="Qualfon Advanced Technology Center LLP">Qualfon Advanced Technology Center LLP</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/wipro-jobs-careers-53141" target="_blank" title="Wipro">Wipro</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/gaba-consultancy-jobs-careers-1379744" target="_blank" title="GABA Consultancy services ">GABA Consultancy services </a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/ciena-jobs-careers-4100048" target="_blank" title="Ciena">Ciena</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/paytm-jobs-careers-198177" target="_blank" title="Paytm">Paytm</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/data-trained-education-jobs-careers-5691152" target="_blank" title="FLIP ROBO TECHNOLOGIES PRIVATE LIMITED ">FLIP ROBO TECHNOLOGIES PRIVATE LIMITED </a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/premium-jobs-jobs-careers-678662" target="_blank" title="AVE-Promagne">AVE-Promagne</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/evelyn-learning-systems-jobs-careers-833688" target="_blank" title="Evelyn Learning Systems">Evelyn Learning Systems</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/gartner-jobs-careers-82369" target="_blank" title="Gartner">Gartner</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/omam-consultants-jobs-careers-859" target="_blank" title="Omam Consultants Pvt. Ltd.">Omam Consultants Pvt. Ltd.</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/jacobs-jobs-careers-68915" target="_blank" title="Jacobs">Jacobs</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/jio-jobs-careers-2700668" target="_blank" title="Jio">Jio</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/exl-jobs-careers-144424" target="_blank" title="EXL">EXL</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/premium-jobs-jobs-careers-678662" target="_blank" title="Accubits Technologies">Accubits Technologies</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/goodyear-jobs-careers-2564454" target="_blank" title="Goodyear">Goodyear</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/vichara-technologies-jobs-careers-447507" target="_blank" title="Vichara Technologies">Vichara Technologies</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com/transorg-solutions-services-jobs-careers-2553404" target="_blank" title="TransOrg Solutions  Services (P) Ltd.">TransOrg Solutions  Services (P) Ltd.</a>
# <a class="subTitle ellipsis fleft" href="https://www.naukri.com
#
# https://www.naukri.com/job-listings-opening-for-data-scientist-rapid-miner-wipro-limited-kochi-cochin-kolkata-gurgaon-gurugram-chennai-coimbatore-bangalore-bengaluru-mumbai-all-areas-pune-hyderabad-7-to-12-years-290322010550?src=jobsearchDesk&sid=16497482159814147&xp=20&px=1
# Boston Consulting Group
#
# https://www.naukri.com/job-listings-opening-for-data-scientist-rapid-miner-wipro-limited-kochi-cochin-kolkata-gurgaon-gurugram-chennai-coimbatore-bangalore-bengaluru-mumbai-all-areas-pune-hyderabad-7-to-12-years-290322010550?src=jobsearchDesk&sid=16497482159814147&xp=20&px=1
# Wipro

# %%
# Job Ratings
for job_elem in job_elems:
    rating_span = job_elem.find('span', class_='starRating fleft dot')
    if rating_span is None:
        continue
    else:
        Ratings = rating_span.text
    print(Ratings)
# Out:
# 4.4
# 4.2
# 3.7
# 4.0
# 3.9
# 4.0
# 3.9
# 4.0
# 3.7
# 4.9
# 4.0
# 4.0
# 3.9
# 4.2
# 4.3
# 4.7

# %%
# Review Counts
for job_elem in job_elems:
    review_span = job_elem.find('a', class_='reviewsCount ml-5 fleft blue-text')
    if review_span is None:
        continue
    else:
        reviews = review_span.text
    print(reviews)
# Out:
# (14 Reviews)
# (139 Reviews)
# (3462 Reviews)
# (6470 Reviews)
# (242 Reviews)
# (29 Reviews)
# (413 Reviews)
# (11938 Reviews)
# (777 Reviews)
# (8 Reviews)
# (303 Reviews)
# (80 Reviews)
# (19723 Reviews)
# (659 Reviews)
# (20 Reviews)
# (2 Reviews)

# %%
# Years of experiece reqired
for job_elem in job_elems:
    Exp = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi experience')
    Exp_span = Exp.find('span',class_='ellipsis fleft fs12 lh16')
    if Exp_span is None:
        continue
    else:
        Experience = Exp_span.text
        print(Experience)
# Out:
# 0-3 Yrs
# 0-1 Yrs
# 3-8 Yrs
# 8-12 Yrs
# 2-4 Yrs
# 0-5 Yrs
# 5-9 Yrs
# 3-8 Yrs
# 3-5 Yrs
# 2-6 Yrs
# 4-8 Yrs
# 8-13 Yrs
# 5-8 Yrs
# 7-12 Yrs
# 7-12 Yrs
# 3-7 Yrs
# 0-1 Yrs
# 5-9 Yrs

# %%
# Salary offer for the job:
for job_elem in job_elems:
    Sal = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi salary')
    Sal_span = Sal.find('span',class_='ellipsis fleft fs12 lh16')
    if Sal_span is None:
        continue
    else:
        Salary = Sal_span.text
        print(Salary)
# Out:
# 2,25,000 - 4,75,000 PA.
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# 3,50,000 - 5,00,000 PA.
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# 11,00,000 - 18,00,000 PA.
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed
# Not disclosed

# %%
# Loation for the job
for job_elem in job_elems:
    Loc = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi location')
    Loc_exp = Loc.find('span',class_='ellipsis fleft fs12 lh16')
    if Loc_exp is None:
        continue
    else:
        Location = Loc_exp.text
    print(Location)
# Out:
# Noida, Gurgaon/Gurugram, Delhi / NCR
# Noida, Bangalore/Bengaluru
# Noida, Kota, Mumbai, Chandigarh, Lucknow, Agra, Gurgaon/Gurugram, Jaipur, Bangalore/Bengaluru
# Gurgaon/Gurugram
# Noida, Bangalore/Bengaluru
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Gurgaon/Gurugram
# Noida, Kota, Mumbai, Chandigarh, Lucknow, Agra, Gurgaon/Gurugram, Jaipur, Bangalore/Bengaluru
# Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Hyderabad/Secunderabad, Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR
# Bangalore/Bengaluru, Delhi / NCR
# Hyderabad/Secunderabad, Pune, Chennai, Gurgaon/Gurugram, Bangalore/Bengaluru
# Mumbai, Delhi, Chennai, Bengaluru
# Kochi/Cochin, Kolkata, Gurgaon/Gurugram, Chennai, Coimbatore, Bangalore/Bengaluru, Mumbai (All Areas), Pune, Hyderabad
# Gurgaon/Gurugram
# Chandigarh, Gurgaon/Gurugram
# Noida

# %%
# No of days since job posted
for job_elem in job_elems:
    Hist = job_elem.find("div",["type br2 fleft grey","type br2 fleft green"])
    Post_Hist = Hist.find('span',class_='fleft fw500')
    if Post_Hist is None:
        continue
    else:
        Post_History = Post_Hist.text
    print(Post_History)
# Out:
# 2 Days Ago
# 1 Day Ago
# 1 Day Ago
# 9 Days Ago
# 30+ Days Ago
# 30 Days Ago
# 11 Days Ago
# 2 Days Ago
# 1 Day Ago
# 3 Days Ago
# 3 Days Ago
# 3 Days Ago
# 10 Days Ago
# 4 Days Ago
# 2 Days Ago
# 30+ Days Ago
# 10 Days Ago
# 23 Days Ago
# 3 Days Ago
# 8 Days Ago

# %%
# import the required libraries
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import requests

# %%
job = input("Enter the job you want to apply for:").replace(' ', '')
location = input("Enter the location you want to apply for:").replace(' ','')
# Out:
# Enter the job you want to apply for:data science
# Enter the location you want to apply for:new delhi

# %%
df = pd.DataFrame(columns=['Title','Company','Ratings','Reviews','Experience','Salary','Location','Job_Post_History','URL'])

# %%
# %%time
for param in range(1,10):
    url = f"https://www.naukri.com/{job}-jobs-in-{location}"

    driver = webdriver.Chrome('chromedriver.exe')
    driver.get(url)

    time.sleep(10)

    soup = BeautifulSoup(driver.page_source,"html.parser")

    # print(soup.prettify())

    driver.close()

    results = soup.find(class_='list')
    job_elems = results.find_all('article',class_='jobTuple bgWhite br4 mb-8')

    for job_elem in job_elems:

        # URL to apply for the job     
        URL = job_elem.find('a',class_='title fw500 ellipsis').get('href')
    #     print(URL.strip())

        # Post Title
        Title = job_elem.find('a',class_='title fw500 ellipsis')

        # Company Name
        Company = job_elem.find('a',class_='subTitle ellipsis fleft')

        # Ratings
        rating_span = job_elem.find('span',class_='starRating fleft dot')
        if rating_span is None:
            continue
        else:
            Ratings = rating_span.text

        # Reviews Counts
        Review_span = job_elem.find('a',class_='reviewsCount ml-5 fleft blue-text')
        if Review_span is None:
            continue
        else:
            Reviews = Review_span.text

        # Years of experience Required
        Exp = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi experience')
        Exp_span = Exp.find('span',class_='ellipsis fleft fs12 lh16')
        if Exp_span is None:
            continue
        else:
            Experience = Exp_span.text

        # Salary offered for the job
        Sal = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi salary')
        Sal_span = Sal.find('span',class_='ellipsis fleft fs12 lh16')
        if Sal_span is None:
            continue
        else:
            Salary = Sal_span.text

        # Location for the job post
        Loc = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi location')
        Loc_exp = Loc.find('span',class_='ellipsis fleft fs12 lh16')
        if Loc_exp is None:
            continue
        else:
            Location = Loc_exp.text

        # Number of days since job posted
        Hist = job_elem.find("div",["type br2 fleft grey","type br2 fleft green"])
        Post_Hist = Hist.find('span',class_='fleft fw500')
        if Post_Hist is None:
            continue
        else:
            Post_History = Post_Hist.text

    #   Appending data to the DataFrame
    df = df.append({'URL':URL,'Title':Title.text,'Company':Company.text,'Ratings':Ratings,'Reviews':Reviews,'Experience':Experience,'Salary':Salary, 'Location':Location, 'Post History':Post_History}, ignore_index=True)
# Out:
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   after removing the cwd from sys.path.
# Wall time: 2min 54s

# %%
df.head()
# Out:
#                      Title   Company Ratings      Reviews Experience  \
# 0  Data Analyst/ Scientist  Anicalls     4.7  (2 Reviews)    5-9 Yrs
# 1  Data Analyst/ Scientist  Anicalls     4.7  (2 Reviews)    5-9 Yrs
# 2  Data Analyst/ Scientist  Anicalls     4.7  (2 Reviews)    5-9 Yrs
# 3  Data Analyst/ Scientist  Anicalls     4.7  (2 Reviews)    5-9 Yrs
# 4  Data Analyst/ Scientist  Anicalls     4.7  (2 Reviews)    5-9 Yrs
#
#           Salary Location Job_Post_History  \
# 0  Not disclosed    Noida              NaN
# 1  Not disclosed    Noida              NaN
# 2  Not disclosed    Noida              NaN
# 3  Not disclosed    Noida              NaN
# 4  Not disclosed    Noida              NaN
#
#                                                  URL Post History
# 0  https://www.naukri.com/job-listings-data-analy...   8 Days Ago
# 1  https://www.naukri.com/job-listings-data-analy...   8 Days Ago
# 2  https://www.naukri.com/job-listings-data-analy...   8 Days Ago
# 3  https://www.naukri.com/job-listings-data-analy...   8 Days Ago
# 4  https://www.naukri.com/job-listings-data-analy...   8 Days Ago

# %%
df.shape
# Out:
# (9, 10)

# %% [markdown]
# # Stack Overflow Scrapper

# %%
import requests
from bs4 import BeautifulSoup
import json

res = requests.get("https://stackoverflow.com/search?q=division+by+zero+error+python")

soup = BeautifulSoup(res.text, "html.parser")

questions_data = {
    "questions": []
}

questions = soup.select(".question-summary")

for que in questions:
    q = que.select_one('.question-hyperlink').getText()
    vote_count = que.select_one('.vote-count-post').getText()
    views = que.select_one('.views').attrs['title']
    questions_data['questions'].append({
        "question": q,
        "views": views,
        "vote_count": vote_count
    })

json_data = json.dumps(questions_data)

print(json_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11820\2607537916.py in <module>
#      16     q = que.select_one('.question-hyperlink').getText()
#      17     vote_count = que.select_one('.vote-count-post').getText()
# ---> 18     views = que.select_one('.views').attrs['title']
#      19     questions_data['questions'].append({
#      20         "question": q,
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="html__responsive" lang="en">
# <head>
# <title>Posts containing 'division by zero error python' - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type">
# <meta content="https://stackoverflow.com/search?q=division+by+zero+error+python" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="stackoverflow.com" name="twitter:domain"/>
# <meta content="Posts containing 'division by zero error python'" itemprop="name" name="twitter:title" property="og:title"/>
# <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
# <script id="webpack-public-path" type="text/uri-list">https://cdn.sstatic.net/</script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script async="" src="https://cdn.sstatic.net/Js/third-party/npm/@stackoverflow/stacks/dist/js/stacks.min.js?v=142fc8338a23"></script>
# <script src="https://cdn.sstatic.net/Js/stub.en.js?v=e700279bb0cc"></script>
# <link href="https://cdn.sstatic.net/Shared/stacks.css?v=098cc8e0cc26" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=c484c344e729" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/secondary.css?v=becb9548f5f1" rel="stylesheet" type="text/css"/>
# <link href="/feeds" rel="alternate" title="Feed of recent questions" type="application/atom+xml"/>
# <style>
#         mark {
#             background-color: transparent;
#             color: inherit;
#         }
#     </style>
# <script>
#         $(function () {
#             $(".js-advanced-tips-toggle").on("click", function(e) {
#                 $(".js-advanced-tips").toggleClass("d-none");
#                 e.preventDefault();
#                 return false;
#             });
#         });
#     </script>
# <link href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=ae3424a7b774" rel="stylesheet" type="text/css"/>
# <script data-module-name="Shared/options.mod" data-role="module-args" type="application/json">{"options":{"locale":"en","serverTime":1649481935,"routeName":"Search/Search","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q\u0026A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"366e7c27760241b1f164e08c51a732442874f0403ea111f68ca236bd4aaf71f9","tid":"8e2f3fc4-38df-7808-884c-7002564f6015","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true,"ab":{"hot_questions_sidebar":{"v":"signupoptincopy","g":3}}},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/stacks-icons","svgIconHash":"8667b5d4a480"}}</script>
# <script data-module-name="Shared/settings.mod" data-role="module-args" type="application/json">{"settings":{"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultFreemiumMaxTrueUpSeats":50,"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"questions":{"enableQuestionTitleLengthLiveWarning":true,"maxTitleSize":150,"questionTitleLengthStartLiveWarningChars":50},"intercom":{"appId":"inf0secd","hostBaseUrl":"https://stacksnippets.net"},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{"enableTables":true},"legal":{"oneTrustConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c"},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}}}</script>
# <script>StackExchange.init();</script>
# <script>
#         StackExchange.using.setCacheBreakers({"Js/adops.en.js":"6da43f5e0a84","Js/ask.en.js":"7ff9a9068fd6","Js/begin-edit-event.en.js":"dd955babf04d","Js/copy-transpiled.en.js":"6e17fb344f2c","Js/events.en.js":"","Js/explore-qlist.en.js":"2b1f34938b8b","Js/full-anon.en.js":"aae83d07d74e","Js/full.en.js":"e659d7d53e1a","Js/highlightjs-loader.en.js":"3c37abf5cb6d","Js/inline-tag-editing.en.js":"c0cbc31e5702","Js/keyboard-shortcuts.en.js":"fa78d9020f1f","Js/markdown-it-loader.en.js":"5818ef89ff9d","Js/moderator.en.js":"4dfc5164bc2c","Js/postCollections-transpiled.en.js":"529276cfb7ae","Js/post-validation.en.js":"09f528ac466a","Js/question-editor.en.js":"","Js/review-v2-transpiled.en.js":"d5c179dadf5b","Js/revisions.en.js":"a86490719687","Js/stacks-editor.en.js":"7c971287f03c","Js/tageditor.en.js":"825c9597ce2d","Js/tageditornew.en.js":"857acd8b77e4","Js/tagsuggestions.en.js":"1bcff7d98f97","Js/unlimited-transpiled.en.js":"7ed67670b600","Js/wmd.en.js":"cce630fdf460","Js/snippet-javascript-codemirror.en.js":"73fce5cc7219"});
#         StackExchange.using("gps", function() {
#              StackExchange.gps.init(false);
#         });
#     </script>
# <noscript id="noscript-css"><style>body,.s-topbar{margin-top:1.9em}</style></noscript>
# </meta></head>
# <body class="unified-theme search-page">
# <div id="notify-container"></div>
# <div id="custom-header"></div>
# <header class="s-topbar ps-fixed t0 l0 js-top-bar">
# <div class="s-topbar--container">
# <a aria-controls="left-sidebar" aria-expanded="false" aria-haspopup="true" class="s-topbar--menu-btn js-left-sidebar-toggle" href="#" role="menuitem"><span></span></a>
# <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">
# <div class="left-sidebar js-unpinned-left-sidebar" data-can-be="left-sidebar" data-is-here-when="sm"></div>
# </div>
# <a class="s-topbar--logo js-gps-track" data-gps-track="top_nav.click({is_current:false, location:26, destination:8})" href="https://stackoverflow.com">
# <span class="-img _glyph">Stack Overflow</span>
# </a>
# <ol class="s-navigation" role="presentation">
# <li class="md:d-none">
# <a class="s-navigation--item js-gps-track" data-ga='["top navigation","about menu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:7})" href="https://stackoverflow.co/">About</a>
# </li>
# <li>
# <a aria-controls="products-popover" class="s-navigation--item js-gps-track js-products-menu" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["top navigation","products menu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:1})" data-s-popover-placement="bottom" data-s-popover-toggle-class="is-selected" href="#">
#                         Products
#                     </a>
# </li>
# <li class="md:d-none">
# <a class="s-navigation--item js-gps-track" data-ga='["top navigation","learn more - teams",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:7})" href="/teams">For Teams</a>
# </li>
# </ol>
# <div aria-hidden="true" class="s-popover ws2 mtn2 p0" id="products-popover" role="menu">
# <div class="s-popover--arrow"></div>
# <ol class="list-reset s-anchors s-anchors__inherit">
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","public qa submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:2})" href="/questions">
# <span class="fs-body1 d-block">Stack Overflow</span>
# <span class="fs-caption d-block fc-light">Public questions &amp; answers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","teams submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:3})" href="/teams">
# <span class="fs-body1 d-block">Stack Overflow for Teams</span>
# <span class="fs-caption d-block fc-light">Where developers &amp; technologists share private knowledge with coworkers</span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","talent submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:5})" href="https://stackoverflow.co/talent">
# <span class="fs-body1 d-block">Talent</span>
# <span class="fs-caption d-block fc-light">
# Build your employer brand                            </span>
# </a>
# </li>
# <li class="m6">
# <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" data-ga='["top navigation","advertising submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:6})" href="https://stackoverflow.co/advertising">
# <span class="fs-body1 d-block">Advertising</span>
# <span class="fs-caption d-block fc-light">Reach developers &amp; technologists worldwide</span>
# </a>
# </li>
# <li class="bg-black-025 bt bc-black-075 py6 px6 bbr-md">
# <a class="fc-light d-block py6 px6 h:fc-black-800 js-gps-track" data-ga='["top navigation","about submenu click",null,null,null]' data-gps-track="top_nav.products.click({location:26, destination:7})" href="https://stackoverflow.co/">About the company</a>
# </li>
# </ol>
# </div>
# <form action="/search" autocomplete="off" class="s-topbar--searchbar js-searchbar" id="search" role="search">
# <div class="s-topbar--searchbar--input-group">
# <input aria-controls="top-search" aria-label="Search" autocomplete="off" class="s-input s-input__search js-search-field" data-action="focus-&gt;s-popover#show" data-controller="s-popover" data-s-popover-placement="bottom-start" maxlength="240" name="q" placeholder="Search…" type="text" value="division by zero error python"/>
# <svg aria-hidden="true" class="s-input-icon s-input-icon__search svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 1 0-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 1 1 2 7a5 5 0 0 1 10 0Z"></path></svg>
# <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial js-top-search-popover" id="top-search" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="js-spinner p24 d-flex ai-center jc-center d-none">
# <div class="s-spinner s-spinner__sm fc-orange-400">
# <div class="v-visible-sr">Loading…</div>
# </div>
# </div>
# <span class="v-visible-sr js-screen-reader-info"></span>
# <div class="js-ac-results overflow-y-auto hmx3 d-none"></div>
# <div aria-describedby="Tips for searching" class="js-search-hints"></div>
# </div>
# </div>
# </form>
# <ol class="s-topbar--content" role="presentation">
# <li class="js-topbar-dialog-corral" role="presentation">
# <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">
# <div class="header fw-wrap">
# <h3 class="flex--item">
# <a href="https://stackoverflow.com">current community</a>
# </h3>
# <div class="flex--item fl1">
# <div class="ai-center d-flex jc-end">
# <button aria-label="Close" class="js-close-button s-btn s-btn__muted p0 ml8 d-none sm:d-block" type="button">
# <svg aria-hidden="true" class="svg-icon iconClear" height="18" viewbox="0 0 18 18" width="18"><path d="M15 4.41 13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 9 10.41 13.59 15 15 13.59 10.41 9 15 4.41Z"></path></svg>
# </button>
# </div>
# </div>
# </div>
# <div class="modal-content bg-powder-050 current-site-container">
# <ul class="current-site">
# <li class="d-flex">
# <div class="fl1">
# <a class="current-site-link site-link js-gps-track d-flex gs8 gsx" data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" href="https://stackoverflow.com">
# <div class="favicon favicon-stackoverflow site-icon flex--item" title="Stack Overflow"></div>
# <span class="flex--item fl1">
#             Stack Overflow
#         </span>
# </a>
# </div>
# <div class="related-links">
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">help</a>
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com/?tab=site&amp;host=stackoverflow.com">chat</a>
# </div>
# </li>
# <li class="related-site d-flex">
# <div class="L-shaped-icon-container">
# <span class="L-shaped-icon"></span>
# </div>
# <a class="site-link js-gps-track d-flex gs8 gsx" data-gps-track="site.switch({ target_site:552, item_type:3 }),site_switcher.click({ item_type:4 })" data-id="552" href="https://meta.stackoverflow.com">
# <div class="favicon favicon-stackoverflowmeta site-icon flex--item" title="Meta Stack Overflow"></div>
# <span class="flex--item fl1">
#             Meta Stack Overflow
#         </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="header" id="your-communities-header">
# <h3>
# your communities            </h3>
# </div>
# <div class="modal-content" id="your-communities-section">
# <div class="call-to-login">
# <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:10 })" href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fsearch%3fq%3ddivision%2bby%2bzero%2berror%2bpython">Sign up</a> or <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:11 })" href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fsearch%3fq%3ddivision%2bby%2bzero%2berror%2bpython">log in</a> to customize your list.                </div>
# </div>
# <div class="header">
# <h3><a href="https://stackexchange.com/sites">more stack exchange communities</a>
# </h3>
# <a class="float-right" href="https://stackoverflow.blog">company blog</a>
# </div>
# <div class="modal-content">
# <div class="child-content"></div>
# </div>
# </div>
# </li>
# <li><a aria-controls="search" aria-haspopup="true" aria-label="Search" class="s-topbar--item s-btn s-btn__icon s-btn__muted d-none sm:d-inline-flex js-searchbar-trigger" href="#" role="button" title="Click to show search"><svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="m18 16.5-5.14-5.18h-.35a7 7 0 1 0-1.19 1.19v.35L16.5 18l1.5-1.5ZM12 7A5 5 0 1 1 2 7a5 5 0 0 1 10 0Z"></path></svg></a></li>
# <li><a class="s-topbar--item s-topbar--item__unset s-btn s-btn__filled ws-nowrap js-gps-track" data-ga='["top navigation","login button click",null,null,null]' data-gps-track="login.click" href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fsearch%3fq%3ddivision%2bby%2bzero%2berror%2bpython" rel="nofollow">Log in</a></li>
# <li><a class="s-topbar--item s-topbar--item__unset ml4 s-btn s-btn__primary ws-nowrap" data-ga='["sign up","Sign Up Navigation","Header",null,null]' href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fsearch%3fq%3ddivision%2bby%2bzero%2berror%2bpython" rel="nofollow">Sign up</a></li>
# </ol>
# </div>
# </header>
# <script>
#         StackExchange.ready(function () { StackExchange.topbar.init(); });
#         StackExchange.scrollPadding.setPaddingTop(50, 10);
#     </script>
# <div class="container">
# <div class="left-sidebar js-pinned-left-sidebar ps-relative" data-is-here-when="md lg" id="left-sidebar">
# <div class="left-sidebar--sticky-container js-sticky-leftnav">
# <nav role="navigation">
# <ol class="nav-links">
# <li class="ps-relative">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:26, destination:8})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                     Home
#                 </div>
# </div>
# </a>
# </li>
# <li>
# <ol class="nav-links">
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Public</li>
# <li class="ps-relative youarehere">
# <a aria-controls="" class="pl8 js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:true, location:26, destination:1})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/questions" id="nav-questions">
# <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" viewbox="0 0 18 18" width="18"><path d="M9 1C4.64 1 1 4.64 1 9c0 4.36 3.64 8 8 8 4.36 0 8-3.64 8-8 0-4.36-3.64-8-8-8ZM8 15.32a6.46 6.46 0 0 1-4.3-2.74 6.46 6.46 0 0 1-.93-5.01L7 11.68v.8c0 .88.12 1.32 1 1.32v1.52Zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.45 6.45 0 0 1 3.83 4.51 6.45 6.45 0 0 1-1.51 5.73v.01Z"></path></svg> <span class="-link--channel-name">Questions</span>
# </a>
# </li>
# <li class="ps-relative">
# <a aria-controls="" class="js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:26, destination:2})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/tags" id="nav-tags">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                     Tags
#                 </div>
# </div>
# </a>
# </li>
# <li class="ps-relative">
# <a aria-controls="" class="js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:26, destination:3})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/users" id="nav-users">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                     Users
#                 </div>
# </div>
# </a>
# </li>
# <li class="ps-relative">
# <a aria-controls="" class="js-gps-track nav-links--link" data-controller="" data-gps-track="top_nav.click({is_current:false, location:26, destination:12})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="https://stackoverflow.com/jobs/companies?so_medium=stackoverflow&amp;so_source=SiteNav" id="nav-companies">
# <div class="d-flex ai-center">
# <div class="flex--item truncate">
#                     Companies
#                 </div>
# </div>
# </a>
# </li>
# <li class="d-flex ml8 mt16 mb4 jc-space-between">
# <div class="flex--item tt-uppercase tt-uppercase fs-fine fc-light">Collectives</div>
# <div class="flex--item fs-fine fc-light">
# <a aria-controls="popover-discover-collectives" class="s-link s-link__inherit mr8 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-gps-track="top_nav.click({is_current:false, location:26, destination:17})" data-s-popover-placement="top" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 1 1 0 12A6 6 0 0 1 7 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="ps-relative">
# <a aria-controls="" class="pl8 ai-center js-gps-track nav-links--link -link__with-icon" data-controller="" data-gps-track="top_nav.click({is_current:false, location:26, destination:18})" data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" data-s-popover-placement="right" href="/collectives" id="nav-collective-discover">
# <svg aria-hidden="true" class="mt-auto fc-orange-400 svg-icon iconStarVerified" height="18" viewbox="0 0 18 18" width="18"><path d="M9.86.89a1.14 1.14 0 0 0-1.72 0l-.5.58c-.3.35-.79.48-1.23.33l-.72-.25a1.14 1.14 0 0 0-1.49.85l-.14.76c-.1.45-.45.8-.9.9l-.76.14c-.67.14-1.08.83-.85 1.49l.25.72c.15.44.02.92-.33 1.23l-.58.5a1.14 1.14 0 0 0 0 1.72l.58.5c.35.3.48.79.33 1.23l-.25.72c-.23.66.18 1.35.85 1.49l.76.14c.45.1.8.45.9.9l.14.76c.14.67.83 1.08 1.49.85l.72-.25c.44-.15.92-.02 1.23.33l.5.58c.46.52 1.26.52 1.72 0l.5-.58c.3-.35.79-.48 1.23-.33l.72.25c.66.23 1.35-.18 1.49-.85l.14-.76c.1-.45.45-.8.9-.9l.76-.14c.67-.14 1.08-.83.85-1.49l-.25-.72c-.15-.44-.02-.92.33-1.23l.58-.5c.52-.46.52-1.26 0-1.72l-.58-.5c-.35-.3-.48-.79-.33-1.23l.25-.72a1.14 1.14 0 0 0-.85-1.49l-.76-.14c-.45-.1-.8-.45-.9-.9l-.14-.76a1.14 1.14 0 0 0-1.49-.85l-.72.25c-.44.15-.92.02-1.23-.33l-.5-.58Zm-.49 2.67L10.6 6.6c.05.15.19.24.34.25l3.26.22c.36.03.5.48.23.71l-2.5 2.1a.4.4 0 0 0-.14.4l.8 3.16a.4.4 0 0 1-.6.44L9.2 12.13a.4.4 0 0 0-.42 0l-2.77 1.74a.4.4 0 0 1-.6-.44l.8-3.16a.4.4 0 0 0-.13-.4l-2.5-2.1a.4.4 0 0 1 .22-.7l3.26-.23a.4.4 0 0 0 .34-.25l1.22-3.03a.4.4 0 0 1 .74 0Z"></path></svg> <span class="-link--channel-name">Explore Collectives</span>
# </a>
# </li>
# </ol>
# </li>
# <li>
# <ol class="nav-links">
# <div class="js-freemium-cta ps-relative">
# <div class="fs-fine tt-uppercase ml8 mt16 mb8 fc-light">Teams</div>
# <div class="bt bl bb bc-black-075 p12 pb6 fc-black-600 blr-sm overflow-hidden">
# <strong class="fc-black-750 mb6">Stack Overflow for Teams</strong>
#         – Start collaborating and sharing organizational knowledge.
#
#         <img alt="" class="wmx100 mx-auto my8 h-auto d-block" height="114" src="https://cdn.sstatic.net/Img/teams/teams-illo-free-sidebar-promo.svg?v=47faa659a05e" width="139"/>
# <a class="w100 s-btn s-btn__primary s-btn__xs bg-orange-400 js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" href="https://try.stackoverflow.co/why-teams/?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta">Create a free Team</a>
# <a class="w100 s-btn s-btn__muted s-btn__xs js-gps-track" data-ga='["teams left navigation - anonymous","left nav free cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: 5 })" href="https://stackoverflow.co/teams">Why Teams?</a>
# </div>
# </div>
# <li class="d-flex ai-center jc-space-between ml8 mt24 mb4 js-create-team-cta d-none">
# <div class="flex--item tt-uppercase fs-fine fc-light">Teams</div>
# <div class="flex--item">
# <a aria-controls="popover-teams-create-cta" class="s-link p12 fc-black-500 h:fc-black-800 js-gps-track" data-action="s-popover#toggle" data-controller="s-popover" data-ga='["teams left navigation - anonymous","left nav show teams info",null,null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: ShowInfo })" data-s-popover-placement="bottom-start" data-s-popover-toggle-class="is-selected" href="javascript:void(0)" role="button">
# <svg aria-hidden="true" class="svg-icon iconInfoSm" height="14" viewbox="0 0 14 14" width="14"><path d="M7 1a6 6 0 1 1 0 12A6 6 0 0 1 7 1Zm1 10V6H6v5h2Zm0-6V3H6v2h2Z"></path></svg>
# </a>
# </div>
# </li>
# <li class="ps-relative js-create-team-cta d-none">
# <a class="pl8 js-gps-track nav-links--link" data-ga='["teams left navigation - anonymous","left nav team click","stackoverflow.com/teams/create/free",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: FreemiumTeamsCreateClick })" href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta" title="Stack Overflow for Teams is a private, secure spot for your organization's questions and answers.">
# <div class="d-flex ai-center">
# <div class="flex--item s-avatar va-middle bg-orange-400">
# <div class="s-avatar--letter mtn1">
# <svg aria-hidden="true" class="svg-icon iconBriefcaseSm" height="14" viewbox="0 0 14 14" width="14"><path d="M4 3a1 1 0 0 1 1-1h4a1 1 0 0 1 1 1v1h.5c.83 0 1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5h-7A1.5 1.5 0 0 1 2 10.5v-5C2 4.67 2.67 4 3.5 4H4V3Zm5 1V3H5v1h4Z"></path></svg>
# </div>
# <svg aria-hidden="true" class="native s-avatar--badge svg-icon iconShieldXSm" height="10" viewbox="0 0 9 10" width="9"><path d="M0 1.84 4.5 0 9 1.84v3.17C9 7.53 6.3 10 4.5 10 2.7 10 0 7.53 0 5.01V1.84Z" fill="var(--white)"></path><path d="M1 2.5 4.5 1 8 2.5v2.51C8 7.34 5.34 9 4.5 9 3.65 9 1 7.34 1 5.01V2.5Zm2.98 3.02L3.2 7h2.6l-.78-1.48a.4.4 0 0 1 .15-.38c.34-.24.73-.7.73-1.14 0-.71-.5-1.23-1.41-1.23-.92 0-1.39.52-1.39 1.23 0 .44.4.9.73 1.14.12.08.18.23.15.38Z" fill="var(--black-500)"></path></svg>
# </div>
# <div class="flex--item pl6">
#                             Create free Team
#                         </div>
# </div>
# </a>
# </li>
# </ol>
# </li>
# </ol>
# </nav>
# </div>
# <div aria-hidden="true" class="s-popover ws2" id="popover-discover-collectives" role="menu">
# <div class="s-popover--arrow"></div>
# <div>
# <svg aria-hidden="true" class="fc-orange-500 float-right ml24 svg-spot spotCollective" height="48" viewbox="0 0 48 48" width="48"><path d="M25.5 7a2.5 2.5 0 1 0 0-5 2.5 2.5 0 0 0 0 5ZM14 18.25c0-.69.56-1.25 1.25-1.25h22.5c.69 0 1.25.56 1.25 1.25V37.5a1 1 0 0 1-1.6.8l-4.07-3.05a1.25 1.25 0 0 0-.75-.25H15.25c-.69 0-1.25-.56-1.25-1.25v-15.5ZM7 24.5a2.5 2.5 0 1 1-5 0 2.5 2.5 0 0 1 5 0ZM25.5 48a2.5 2.5 0 1 0 0-5 2.5 2.5 0 0 0 0 5ZM48 24.5a2.5 2.5 0 1 1-5 0 2.5 2.5 0 0 1 5 0Z" opacity=".2"></path><path d="M21 3.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0ZM24.5 2a1.5 1.5 0 1 0 0 3 1.5 1.5 0 0 0 0-3ZM0 23.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0ZM3.5 22a1.5 1.5 0 1 0 0 3 1.5 1.5 0 0 0 0-3ZM21 44.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0Zm3.5-1.5a1.5 1.5 0 1 0 0 3 1.5 1.5 0 0 0 0-3Zm20-23a3.5 3.5 0 1 0 0 7 3.5 3.5 0 0 0 0-7ZM43 23.5a1.5 1.5 0 1 1 3 0 1.5 1.5 0 0 1-3 0Zm-23.23-3.14a1 1 0 0 1-.13 1.4l-2.08 1.74 2.08 1.73a1 1 0 1 1-1.28 1.54l-2.42-2.02a1.63 1.63 0 0 1 0-2.5l2.42-2.02a1 1 0 0 1 1.4.13Zm7.59 1.41a1 1 0 1 1 1.28-1.54l2.42 2.02c.78.65.78 1.85 0 2.5l-2.42 2.02a1 1 0 1 1-1.28-1.54l2.08-1.73-2.08-1.73ZM24.12 18a1 1 0 0 1 .87 1.12l-1 8a1 1 0 1 1-1.98-.24l1-8a1 1 0 0 1 1.11-.87Zm-11.87-5C11.01 13 10 14 10 15.25v15.5c0 1.24 1 2.25 2.25 2.25h17.33c.06 0 .11.02.15.05l4.07 3.05a2 2 0 0 0 3.2-1.6V15.25c0-1.24-1-2.25-2.25-2.25h-22.5ZM12 15.25c0-.14.11-.25.25-.25h22.5c.14 0 .25.11.25.25V34.5l-4.07-3.05a2.2 2.2 0 0 0-1.35-.45H12.25a.25.25 0 0 1-.25-.25v-15.5Zm7.24-10.68a1 1 0 1 0-.48-1.94A22.04 22.04 0 0 0 2.91 17.7a1 1 0 1 0 1.92.58 20.04 20.04 0 0 1 14.4-13.72Zm11.05-1.66a1 1 0 0 0-.58 1.92c6.45 1.92 11.54 7 13.46 13.46a1 1 0 1 0 1.92-.58 22.05 22.05 0 0 0-14.8-14.8ZM4.57 28.76a1 1 0 0 0-1.94.48 22.03 22.03 0 0 0 16.13 16.13 1 1 0 1 0 .48-1.94A20.03 20.03 0 0 1 4.57 28.76Zm40.8.48a1 1 0 1 0-1.94-.48 20.04 20.04 0 0 1-13.72 14.41 1 1 0 0 0 .58 1.92 22.04 22.04 0 0 0 15.08-15.85Z"></path></svg>
# <div class="pt4 fw-bold">Collectives on Stack Overflow</div>
# <p class="my16 fs-caption fc-medium">Find centralized, trusted content and collaborate around the technologies you use most.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-gps-track="top_nav.click({is_current:false, location:26, destination:18})" href="/collectives">
#                     Learn more
#                 </a>
# </div>
# </div>
# <div aria-hidden="true" class="s-popover" id="popover-teams-create-cta" role="menu">
# <div class="s-popover--arrow"></div>
# <div class="ps-relative overflow-hidden">
# <p class="mb2"><strong>Teams</strong></p>
# <p class="mb12 fs-caption fc-black-400">Q&amp;A for work</p>
# <p class="mb12 fs-caption fc-medium">Connect and share knowledge within a single location that is structured and easy to search.</p>
# <a class="js-gps-track s-btn s-btn__primary s-btn__xs" data-ga='["teams left navigation - anonymous","left nav cta","stackoverflow.com/teams",null,null]' data-gps-track="teams.create.left-sidenav.click({ Action: CtaClick })" href="https://stackoverflow.co/teams">
#                     Learn more
#                 </a>
# </div>
# <div class="ps-absolute t8 r8">
# <svg aria-hidden="true" class="fc-orange-500 svg-spot spotPeople" height="48" viewbox="0 0 48 48" width="48"><path d="M13.5 28a4.5 4.5 0 1 0 0-9 4.5 4.5 0 0 0 0 9ZM7 30a1 1 0 0 1 1-1h11a1 1 0 0 1 1 1v5h11v-5a1 1 0 0 1 1-1h12a1 1 0 0 1 1 1v10a2 2 0 0 1-2 2H33v5a1 1 0 0 1-1 1H20a1 1 0 0 1-1-1v-5H8a1 1 0 0 1-1-1V30Zm25-6.5a4.5 4.5 0 1 0 9 0 4.5 4.5 0 0 0-9 0ZM24.5 34a4.5 4.5 0 1 0 0-9 4.5 4.5 0 0 0 0 9Z" opacity=".2"></path><path d="M16.4 26.08A6 6 0 1 0 7.53 26C5.64 26.06 4 27.52 4 29.45V40a1 1 0 0 0 1 1h9a1 1 0 1 0 0-2h-4v-7a1 1 0 1 0-2 0v7H6v-9.55c0-.73.67-1.45 1.64-1.45H16a1 1 0 0 0 .4-1.92ZM12 18a4 4 0 1 1 0 8 4 4 0 0 1 0-8Zm16.47 14a6 6 0 1 0-8.94 0A3.6 3.6 0 0 0 16 35.5V46a1 1 0 0 0 1 1h14a1 1 0 0 0 1-1V35.5c0-1.94-1.64-3.42-3.53-3.5ZM20 28a4 4 0 1 1 8 0 4 4 0 0 1-8 0Zm-.3 6h8.6c1 0 1.7.75 1.7 1.5V45h-2v-7a1 1 0 1 0-2 0v7h-4v-7a1 1 0 1 0-2 0v7h-2v-9.5c0-.75.7-1.5 1.7-1.5ZM42 22c0 1.54-.58 2.94-1.53 4A3.5 3.5 0 0 1 44 29.45V40a1 1 0 0 1-1 1h-9a1 1 0 1 1 0-2h4v-7a1 1 0 1 1 2 0v7h2v-9.55A1.5 1.5 0 0 0 40.48 28H32a1 1 0 0 1-.4-1.92A6 6 0 1 1 42 22Zm-2 0a4 4 0 1 0-8 0 4 4 0 0 0 8 0Z"></path><g opacity=".35"><path d="M17 10a1 1 0 011-1h12a1 1 0 110 2H18a1 1 0 01-1-1Zm1-5a1 1 0 100 2h12a1 1 0 100-2H18ZM14 1a1 1 0 00-1 1v12a1 1 0 001 1h5.09l4.2 4.2a1 1 0 001.46-.04l3.7-4.16H34a1 1 0 001-1V2a1 1 0 00-1-1H14Zm1 12V3h18v10h-5a1 1 0 00-.75.34l-3.3 3.7-3.74-3.75a1 1 0 00-.71-.29H15Z"></path></g></svg>
# </div>
# </div>
# </div>
# <div class="snippet-hidden" id="content">
# <div id="mainbar">
# <div class="d-flex mb24 jc-space-between fw-wrap ai-start">
# <h1 class="flex--item fl1 fs-headline1 mb0">
# Search Results            </h1>
# <div class="d-flex ai-center fl1 jc-end ml32">
# <div class="flex--item mr8">
# <a class="js-advanced-tips-toggle" href="#">Advanced Search Tips</a>
# </div>
# <div class="ml12 aside-cta flex--item print:d-none">
# <a class="ws-nowrap s-btn s-btn__primary" href="/questions/ask">
#         Ask Question
#     </a>
# </div>
# </div>
# </div>
# <table class="s-table s-table__bx-simple mb24 d-none js-advanced-tips">
# <thead>
# <tr>
# <th class="s-table--cell2" scope="col">Search type</th>
# <th scope="col">Search syntax</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th scope="row">Tags</th>
# <td class="ff-mono">[tag]</td>
# </tr>
# <tr>
# <th scope="row">Exact</th>
# <td class="ff-mono">"words here"</td>
# </tr>
# <tr>
# <th scope="row">Author</th>
# <td class="ff-mono">
#                     user:1234<br/>
#                     user:me <span class="fc-light">(yours)</span>
# </td>
# </tr>
# <tr>
# <th scope="row">Score</th>
# <td class="ff-mono">
#                     score:3 <span class="fc-light">(3+)</span><br/>
#                     score:0 <span class="fc-light">(none)</span>
# </td>
# </tr>
# <tr>
# <th scope="row">Answers</th>
# <td class="ff-mono">
#                     answers:3 <span class="fc-light">(3+)</span><br/>
#                     answers:0 <span class="fc-light">(none)</span><br/>
#                     isaccepted:yes<br/>
#                     hasaccepted:no<br/>
#                     inquestion:1234
#                 </td>
# </tr>
# <tr>
# <th scope="row">Views</th>
# <td class="ff-mono">views:250</td>
# </tr>
# <tr>
# <th scope="row">Code</th>
# <td class="ff-mono">code:"if (foo != bar)"</td>
# </tr>
# <tr>
# <th scope="row">Sections</th>
# <td class="ff-mono">
#                     title:apples<br/>
#                     body:"apples oranges"
#                 </td>
# </tr>
# <tr>
# <th scope="row">URL</th>
# <td class="ff-mono">url:"*.example.com"</td>
# </tr>
# <tr>
# <th scope="row">Bookmarks</th>
# <td class="ff-mono">
#                     inbookmarks:mine<br/>
#                     inbookmarks:1234
#                 </td>
# </tr>
# <tr>
# <th scope="row">Status</th>
# <td class="ff-mono">
#                     closed:yes<br/>
#                     duplicate:no<br/>
#                     migrated:no<br/>
#                     wiki:no
#                 </td>
# </tr>
# <tr>
# <th scope="row">Types</th>
# <td class="ff-mono">
#                     is:question<br/>
#                     is:answer
#                         <br/>is:article
#                 </td>
# </tr>
# <tr>
# <th scope="row">Exclude</th>
# <td class="ff-mono">
#                     -[tag]<br/>
#                     -apples
#                 </td>
# </tr>
# <tr>
# <th scope="row">Collective</th>
# <td class="ff-mono">
#                         collective:"Name"
#                     </td>
# </tr>
# <tr>
# <td class="" colspan="2">
#                     For more details on advanced search <a href="https://stackoverflow.com/help/searching">visit our help page</a>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="mb24 fs-caption fc-light lh-xs">
# <div class="mb8">Results for division by zero error python</div>
# <div>Search options                                 <span class="fw-bold">not deleted</span>
# </div>
# </div>
# <div class="d-flex ai-center mb16">
# <div class="flex--item fl1 fs-body3 mr12">
#                 232 results
#             </div>
# <div class="flex--item">
# <div class="d-flex s-btn-group js-filter-btn">
# <a class="js-sort-preference-change youarehere is-selected flex--item s-btn s-btn__muted s-btn__outlined" data-nav-xhref="" data-shortcut="" data-value="relevance" href="/search?tab=relevance&amp;q=division%20by%20zero%20error%20python" title="Search results with best match to search terms">
#             Relevance</a>
# <a class="js-sort-preference-change flex--item s-btn s-btn__muted s-btn__outlined" data-nav-xhref="" data-shortcut="" data-value="newest" href="/search?tab=newest&amp;q=division%20by%20zero%20error%20python" title="Newest search results">
#             Newest</a>
# <nav class="d-flex ps-relative">
# <a class="s-btn s-btn__muted s-btn__outlined s-btn__dropdown blr0 brr-sm js-dropdown-toggle">More</a>
# <ul class="dropdown dropdown-questions-filters d-block d-none">
# <li><a class="disabled" data-nav-xhref="" data-shortcut="" data-value="active" href="/search?tab=active&amp;q=division%20by%20zero%20error%20python" title="Recently active search results">Active</a></li>
# <li><a class="disabled" data-nav-xhref="" data-shortcut="" data-value="votes" href="/search?tab=votes&amp;q=division%20by%20zero%20error%20python" title="Highest scored search results">Score</a></li>
# </ul>
# </nav>
# <script>
#             StackExchange.ready(function () {
#                 $(".js-dropdown-toggle").on("click", function(e) {
#                     var dropdown = $(this).next(".dropdown");
#
#                     e.preventDefault();
#                     e.stopPropagation();
#
#                     dropdown.toggleClass("d-none");
#
#                     // Hide the dropdown when clicking outside
#                     $(document).one("click", function closeMenu (e){
#                         if(dropdown.has(e.target).length === 0){
#                             dropdown.addClass("d-none");
#                         } else {
#                             $(document).one("click", closeMenu);
#                         }
#                     });
#                 });
#             });
#         </script>
# </div>
# </div>
# </div>
# <div class="flush-left js-search-results">
# <div>
# <div class="question-summary search-result" data-position="1" id="question-summary-26772824">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered">
# <strong>2</strong>answers
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/26772824/division-by-zero-error-on-dictionary-python?r=SearchResults&amp;s=1|184.6160" href="/questions/26772824/division-by-zero-error-on-dictionary-python?r=SearchResults" title="division by zero error on dictionary python">
# Q: division by zero error on dictionary python        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 However, when I try to do sum(v)/len(v) for the average part, I get <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span> <span class="fw-bold">error</span>. … To avoid the <span class="fw-bold">error</span>, I tried to return the empty value from the dictionary to 0, but I just do not know how to do so. Please Help. …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2014-11-06 06:10:05Z">Nov 6, 2014</span> by <a href="/users/4221512/steffen-you">Steffen You</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="2" id="question-summary-57459996">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered-accepted">
# <strong>1</strong>answer
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/57459996/how-to-avoid-division-by-zero-error-in-python?r=SearchResults&amp;s=2|167.7868" href="/questions/57459996/how-to-avoid-division-by-zero-error-in-python?r=SearchResults" title="How to avoid division by zero error in python">
# Q: How to avoid division by zero error in python        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 When it comes to the last part, the <span class="fw-bold">division</span> between the intersection and union, I can't overcome the 'float <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span>' part. … <span class="fw-bold">by</span> <span class="fw-bold">zero</span> …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python t-machine-learning">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag flex--item" href="/questions/tagged/machine-learning" rel="tag" title="show questions tagged 'machine-learning'">machine-learning</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2019-08-12 11:04:03Z">Aug 12, 2019</span> by <a href="/users/10571813/paul-k">Paul K</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="3" id="question-summary-29836964">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>23</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered-accepted">
# <strong>2</strong>answers
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/29836964/error-python-zerodivisionerror-division-by-zero?r=SearchResults&amp;s=3|162.8994" href="/questions/29836964/error-python-zerodivisionerror-division-by-zero?r=SearchResults" title="Error python : [ZeroDivisionError: division by zero]">
# Q: Error python : [ZeroDivisionError: division by zero]        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 I faced an <span class="fw-bold">error</span> when I run my program using <span class="fw-bold">python</span>:
# The <span class="fw-bold">error</span> is like this:
# ZeroDivisionError: <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span>
#
# My program is similar to this:
# In [55]:
#
# x = 0
# y = 0
# z = x/y
# -------------------------- … <span class="fw-bold">by</span> <span class="fw-bold">zero</span>
#
# Thus, I want to ask, how to avoid that <span class="fw-bold">error</span> in <span class="fw-bold">python</span>. …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2015-04-24 01:04:26Z">Apr 24, 2015</span> by <a href="/users/4744765/markov-zain">markov zain</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="4" id="question-summary-69566317">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>1</strong></span>
# <div class="viewcount">vote</div>
# </div>
# </div>
# <div class="status answered-accepted">
# <strong>1</strong>answer
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/69566317/python-float-division-by-zero-when-plotting-treemap-chart?r=SearchResults&amp;s=4|157.6793" href="/questions/69566317/python-float-division-by-zero-when-plotting-treemap-chart?r=SearchResults" title="python float division by zero when plotting treemap chart">
# Q: python float division by zero when plotting treemap chart        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 I'm new to <span class="fw-bold">python</span> matplotlib and trying to plot a treemap chart, thanks in advance! … squarify.plot(sizes=df['vvmins'], label=df['category_name'], alpha=.8)
# plt.axis('off')
# plt.show()
#
# then the 'float <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span>' <span class="fw-bold">error</span> show up, my data set is like below(dummy): …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python t-matplotlib t-treemap">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag flex--item" href="/questions/tagged/matplotlib" rel="tag" title="show questions tagged 'matplotlib'">matplotlib</a> <a class="post-tag flex--item" href="/questions/tagged/treemap" rel="tag" title="show questions tagged 'treemap'">treemap</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2021-10-14 06:58:27Z">Oct 14, 2021</span> by <a href="/users/15669960/bellasere">Bellasere</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="5" id="question-summary-17345157">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>2</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered-accepted">
# <strong>4</strong>answers
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/17345157/python-list-comphrehension-with-test-to-avoid-division-by-zero?r=SearchResults&amp;s=5|151.8425" href="/questions/17345157/python-list-comphrehension-with-test-to-avoid-division-by-zero?r=SearchResults" title="Python - List comphrehension with test to avoid division by zero">
# Q: Python - List comphrehension with test to avoid division by zero        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 a and b are 1 dimensional numpy arrays (or <span class="fw-bold">python</span> lists):
#
# I am doing this:
#
# &gt;&gt;&gt; c = [x/y for x,y in zip(a,b)]
#
#
# Occasionally b has a <span class="fw-bold">zero</span> in it - so a <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span> <span class="fw-bold">error</span> occurs. …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python t-list t-numpy">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag flex--item" href="/questions/tagged/list" rel="tag" title="show questions tagged 'list'">list</a> <a class="post-tag flex--item" href="/questions/tagged/numpy" rel="tag" title="show questions tagged 'numpy'">numpy</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2013-06-27 13:55:22Z">Jun 27, 2013</span> by <a href="/users/1461850/atomh33ls">atomh33ls</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="6" id="question-summary-46965957">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>0</strong></span>
# <div class="viewcount">votes</div>
# </div>
# </div>
# <div class="status answered">
# <strong>1</strong>answer
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/46965957/bypass-error-division-by-zero-when-doing-a-loop-python?r=SearchResults&amp;s=6|144.7562" href="/questions/46965957/bypass-error-division-by-zero-when-doing-a-loop-python?r=SearchResults" title="Bypass error Division by zero when doing a loop - Python">
# Q: Bypass error Division by zero when doing a loop - Python        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 New using <span class="fw-bold">Python</span> :) I am trying to normalise my data using different columns however, it sometimes occur that some columns I am using to make <span class="fw-bold">division</span> have value = 0. … Which then give me <span class="fw-bold">error</span>: ZeroDivisionError <span class="fw-bold">by</span> <span class="fw-bold">zero</span>.
#
# I have one dataframe mergedfs and loop through columns to calculate normalised values. …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python">
# <a class="post-tag flex--item" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a>
# </div>
# <div class="started float-right">
# asked <span class="relativetime" title="2017-10-27 00:58:20Z">Oct 27, 2017</span> by <a href="/users/8787119/flora">Flora</a> </div>
# </div>
# </div>
# <div class="question-summary search-result" data-position="7" id="question-summary-44002078">
# <div class="statscontainer">
# <div class="stats">
# <div class="vote">
# <div class="votes">
# <span class="vote-count-post"><strong>1</strong></span>
# <div class="viewcount">vote</div>
# </div>
# </div>
# <div class="status unanswered">
# <strong>0</strong>answers
#                     </div>
# </div>
# </div>
# <div class="summary">
# <div class="result-link">
# <h3>
# <a class="question-hyperlink" data-searchsession="/questions/44002078/getting-zerodivisionerror-float-division-by-zero?r=SearchResults&amp;s=7|144.6232" href="/questions/44002078/getting-zerodivisionerror-float-division-by-zero?r=SearchResults" title="Getting ZeroDivisionError: float division by zero">
# Q: Getting ZeroDivisionError: float division by zero        </a>
# </h3>
# </div>
# <div class="excerpt">
#                 Exception in <span class="fw-bold">python</span> callback function evaluation:
# ZeroDivisionError('float <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span>',):
# Traceback (most recent call last):
# File "graphlab\cython\cy_pylambda_workers.pyx", line 450, in graphlab.cython.cy_pylambda_workers … <span class="fw-bold">by</span> <span class="fw-bold">zero</span>
#
#
# The <span class="fw-bold">error</span> seems very similar to : <span class="fw-bold">Python</span> 2.7 - GraphLab : ZeroDivisionError: float <span class="fw-bold">division</span> <span class="fw-bold">by</span> <span class="fw-bold">zero</span>, but I haven't been able to figure it out. …
#             </div>
# <div class="tags d-flex gs4 fw-wrap mt2 t-python t-python-2û7 t-graphlab">
# ...
#     var clc = clc || {};
#     clc.collapse = { sb: !0, 'tag-sponsorship': !0, lb: !0, mlb: !0, smlb: !0, bmlb: !0, 'mobile-below-question': !0 };
#     clc.options = clc.options || {};
#     clc.options.sf = !0;
#     clc.options.hb = !1;
#     clc.options.ll = !0;
#     clc.options.tlb_position = 0;
#     clc.options.targeting_consent = !1;
#     clc.options.performance_consent = !1;
#         clc.cmd = clc.cmd || [];
#         clc.cmd.push(function () { window.clc_request='A4jv_l_pGdoIAAAAAAAAAAACAAAAAQAAAAAAAAAAAABPh4J6TleGcbLl'; clc.load(); });
#         clc.dfp = clc.dfp || {};
#         clc.dfp.targeting = {};
#
#         if (window.location.hash.indexOf('ads:cat=cp') >= 0)
#         {
#             clc.dfp.targeting.CompanyPageAd = '1';
#         }
#
#         clc.dfp.targeting.TargetingConsent = ['false'];
#
#         const urlParams = new URLSearchParams(window.location.search);
#         if (urlParams.has('dfptestads')) {
#             const dfptestads = urlParams.get('dfptestads');
#             clc.dfp.targeting.DfpTestAds = dfptestads;
#         }
#
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.cmd.push(function () { clc.dfp.load(); });
#         StackExchange.ready(function () { googletag.cmd.push(function () { StackExchange.ads.init(googletag, '/ads/report-ad', 'Report this ad') }) });
# </script>
# <footer class="site-footer js-footer" id="footer" role="contentinfo">
# <div class="site-footer--container">
# <div class="site-footer--logo">
# <a href="https://stackoverflow.com"><svg aria-hidden="true" class="native svg-icon iconLogoGlyphMd" height="37" viewbox="0 0 32 37" width="32"><path d="M26 33v-9h4v13H0V24h4v9h22Z" fill="#BCBBBB"></path><path d="m21.5 0-2.7 2 9.9 13.3 2.7-2L21.5 0ZM26 18.4 13.3 7.8l2.1-2.5 12.7 10.6-2.1 2.5ZM9.1 15.2l15 7 1.4-3-15-7-1.4 3Zm14 10.79.68-2.95-16.1-3.35L7 23l16.1 2.99ZM23 30H7v-3h16v3Z" fill="#F48024"></path></svg></a>
# </div>
# <nav class="site-footer--nav">
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 26, link: 15})" href="https://stackoverflow.com">Stack Overflow</a></h5>
# <ul class="-list js-primary-footer-links">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 16})" href="/questions">Questions</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 3 })" href="/help">Help</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 26, link: 19 })" href="https://stackoverflow.com/?products">Products</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-ga='["teams traffic","footer - site nav","stackoverflow.com/teams",null,{"dimension4":"teams"}]' data-gps-track="footer.click({ location: 26, link: 29 })" href="https://stackoverflow.co/teams">Teams</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 21 })" href="https://stackoverflow.co/advertising">Advertising</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 40 })" href="https://stackoverflow.co/collectives">Collectives</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 20 })" href="https://stackoverflow.co/talent">Talent</a></li>
# </ul>
# </div>
# <div class="site-footer--col">
# <h5 class="-title"><a class="js-gps-track" data-gps-track="footer.click({ location: 26, link: 1 })" href="https://stackoverflow.co/">Company</a></h5>
# <ul class="-list">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 1 })" href="https://stackoverflow.co/">About</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 27 })" href="https://stackoverflow.co/company/press">Press</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 9 })" href="https://stackoverflow.co/company/work-here">Work Here</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 7 })" href="https://stackoverflow.com/legal">Legal</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 8 })" href="https://stackoverflow.com/legal/privacy-policy">Privacy Policy</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 37 })" href="https://stackoverflow.com/legal/terms-of-service">Terms of Service</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 13 })" href="https://stackoverflow.co/company/contact">Contact Us</a></li>
# <li class="" id="consent-footer-link"><a class="js-gps-track -link js-cookie-settings" data-consent-popup-loader="footer" data-gps-track="footer.click({ location: 26, link: 38 })" href="#">Cookie Settings</a></li>
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link: 39 })" href="https://stackoverflow.com/legal/cookie-policy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--categories-nav">
# <div>
# <h5 class="-title"><a data-gps-track="footer.click({ location: 26, link: 30 })" href="https://stackexchange.com">Stack Exchange Network</a></h5>
# <ul class="-list">
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#technology">
#                                     Technology
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#culturerecreation">
#                                     Culture &amp; recreation
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#lifearts">
#                                     Life &amp; arts
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#science">
#                                     Science
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#professional">
#                                     Professional
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://stackexchange.com/sites#business">
#                                     Business
#                                 </a>
# </li>
# <li class="mt16 md:mt0">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://api.stackexchange.com/">
#                                     API
#                                 </a>
# </li>
# <li>
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 24 })" href="https://data.stackexchange.com/">
#                                     Data
#                                 </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="site-footer--copyright fs-fine md:mt24">
# <ul class="-list -social md:mb8">
# <li><a class="js-gps-track -link" data-gps-track="footer.click({ location: 26, link:4 })" href="https://stackoverflow.blog?blb=1">Blog</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 31 })" href="https://www.facebook.com/officialstackoverflow/">Facebook</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 32 })" href="https://twitter.com/stackoverflow">Twitter</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 33 })" href="https://linkedin.com/company/stack-overflow">LinkedIn</a></li>
# <li><a class="-link js-gps-track" data-gps-track="footer.click({ location: 26, link: 36 })" href="https://www.instagram.com/thestackoverflow">Instagram</a></li>
# </ul>
# <p class="md:mb0">
# Site design / logo © 2022 Stack Exchange Inc; user contributions licensed under <a href="https://stackoverflow.com/help/licensing">cc by-sa</a>.                    <span id="svnrev">rev 2022.4.8.41922</span>
# </p>
# </div>
# </div>
# </footer>
# <noscript>
# <div id="noscript-warning">Stack Overflow works best with JavaScript enabled
#             <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=17440561&amp;cv=3.6.0&amp;cj=1"/>
# </div>
# </noscript>
# <script>
# (function(i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { (i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m);
#             })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#             StackExchange.ready(function () {
#
#                 StackExchange.ga.init({
#                     autoLink: ["stackoverflow.blog","info.stackoverflowsolutions.com","stackoverflowsolutions.com"],
#                     sendTitles: true,
#                     tracker: window.ga,
#                     trackingCodes: [
#                         'UA-108242619-1'
#                     ],
#                         checkDimension: 'dimension42'
#                 });
#
#
#
#
#
#                     StackExchange.ga.setDimension('dimension3', 'Search/Search');
#
#
#                 StackExchange.ga.setDimension('dimension7', "1649481935.2134008239");
#
#                 StackExchange.ga.trackPageView();
#             });
#                 </script>
# <div class="ff-sans ps-fixed z-nav-fixed ws4 sm:w-auto p32 sm:p16 bg-black-750 fc-white bar-lg b16 l16 r16 js-consent-banner">
# <svg aria-hidden="true" class="mln4 mb24 sm:d-none svg-spot spotCookieLg" height="96" style="color: var(--theme-button-filled-background-color)" viewbox="0 0 96 96" width="96">
# <path d="M35 45.5a7.5 7.5 0 11-15 0 7.5 7.5 0 0115 0zM63.5 63a7.5 7.5 0 100-15 7.5 7.5 0 000 15zm-19 19a7.5 7.5 0 100-15 7.5 7.5 0 000 15z" opacity=".2"></path>
#                             Accept all cookies
#                         </button>
# <button class="flex--item s-btn s-btn__filled js-cookie-settings" data-consent-popup-loader="banner">
#                             Customize settings
#                         </button>
# </div>
# </div>
# <div class="d-none" id="onetrust-consent-sdk"></div>
# <div data-controller="s-modal" id="onetrust-banner-sdk"></div>
# <div class="d-none" id="ot-pc-content"></div>
# <div class="d-none" id="onetrust-style"> </div>
# <div class="d-none js-consent-banner-version" data-consent-banner-version="baseline"></div>
# </body>
# </html>

# %%
find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead

# %%
import bs4
import requests
from selenium import webdriver
import os
import time
from selenium.webdriver.common.by import By

def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)



chromePath=r'chromedriver.exe'
driver=webdriver.Chrome(chromePath)

search_image = input("Enter image you want to download..").replace(' ', '+')
search_URL = f"https://www.google.com/search?q={search_image}&source=lnms&tbm=isch"
driver.get(search_URL)

#creating a directory to save images
folder_name = f'images/{search_image}'
if not os.path.isdir(folder_name):
    os.makedirs(folder_name)


#//*[@id="islrg"]/div[1]/div[1]
#//*[@id="islrg"]/div[1]/div[50]
#//*[@id="islrg"]/div[1]/div[25]
#//*[@id="islrg"]/div[1]/div[75]
#//*[@id="islrg"]/div[1]/div[350]


#Scrolling all the way up
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll('div', {'class':"isv-r PNCib MSM1fd BUooTd"} )

print(len(containers))

len_containers = len(containers)

for i in range(1, len_containers+1):
    if i % 25 == 0:
        continue

    xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)

    previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
    previewImageElement = driver.find_element(by=By.XPATH, value=previewImageXPath)
    previewImageURL = previewImageElement.get_attribute("src")
    #print("preview URL", previewImageURL)


    #print(xPath)


    driver.find_element(by=By.XPATH, value=xPath).click()
    #time.sleep(3)

    #//*[@id="islrg"]/div[1]/div[16]/a[1]/div[1]/img

    #input('waawgawg another wait')

    # page = driver.page_source
    # soup = bs4.BeautifulSoup(page, 'html.parser')
    # ImgTags = soup.findAll('img', {'class': 'n3VNCb', 'jsname': 'HiaYvf', 'data-noaft': '1'})
    # print("number of the ROI tags", len(ImgTags))
    # link = ImgTags[1].get('src')
    # #print(len(ImgTags))
    # #print(link)
    #
    # n=0
    # for tag in ImgTags:
    #     print(n, tag)
    #     n+=1
    # print(len(ImgTags))

    #/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img

    #It's all about the wait

    timeStarted = time.time()
    while True:

        imageElement = driver.find_element(by=By.XPATH, value="""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img""")
        imageURL= imageElement.get_attribute('src')

        if imageURL != previewImageURL:
            #print("actual URL", imageURL)
            break

        else:
            #making a timeout if the full res image can't be loaded
            currentTime = time.time()

            if currentTime - timeStarted > 10:
                print("Timeout! Will download a lower resolution image and move onto the next one")
                break


    #Downloading image
    try:
        download_image(imageURL, folder_name, i)
        print("Downloaded element %s out of %s total. URL: %s" % (i, len_containers + 1, imageURL))
    except:
        print("Couldn't download an image %s, continuing downloading the next one"%(i))

    #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img
    #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img
# Out:
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# Enter image you want to download..bugatti
# 48
# Downloaded element 1 out of 49 total. URL: https://upload.wikimedia.org/wikipedia/commons/1/16/Bugatti_Divo%2C_GIMS_2019%2C_Le_Grand-Saconnex_%28GIMS0029%29.jpg
# Downloaded element 2 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p54/se-image-4799f9106491ebb58ca3351f6df5c44a.jpg
# Downloaded element 3 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p1/se-image-e273a881495acbebe4fc6f0a150b8678.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Couldn't download an image 4, continuing downloading the next one
# Downloaded element 5 out of 49 total. URL: https://cdn.motor1.com/images/mgl/6MGkl/s1/bugatti-chiron-pur-sport.webp
# Downloaded element 6 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p245/se-image-a58e30ad906c90155912fb3ad490ab6b.jpg
# Downloaded element 7 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p1/se-image-c4a9cdcf0a58353aa5323d397bde7f34.jpg
# Downloaded element 8 out of 49 total. URL: https://newsroom.bugatti/press-releases/2019/191129_edition_elegance/bugatti_chiron_noir_matt.jpg
# Downloaded element 9 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p1/se-image-2a3483d97e4b6e79cf80d3013d9ca4dc.jpg
# Downloaded element 10 out of 49 total. URL: https://hips.hearstapps.com/hmg-prod/images/02-ss300p-3i4-front-1567937037.jpg
# Downloaded element 11 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p508/se-image-ac6ebcbfe2c9abf5d5b4b25909113e74.jpg
# Downloaded element 12 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/d/a/csm_Desktop_Stage_v4_075c72c979.png
# Downloaded element 13 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p121/se-image-4f750982624e527a8b1003408e4febcf.jpg
# Downloaded element 14 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p54/se-image-8d5311988169e20af0fb3df4b9c4123d.jpg
# Downloaded element 15 out of 49 total. URL: https://s.abcnews.com/images/Business/bugatti-01-ht-jc-210629_1624984429880_hpMain_16x9_1600.jpg
# Downloaded element 16 out of 49 total. URL: https://media.wired.com/photos/59547e60ce3e5e760d52d429/master/pass/02_Bugatti-VGT_photo_ext_WEB.jpg
# Downloaded element 17 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p316/se-image-631f66543efc653cf39b477f53f99562.jpg
# Downloaded element 18 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/6/4/csm_HEADER_mobile_82e15b4784.jpg
# Downloaded element 19 out of 49 total. URL: https://i.ytimg.com/vi/LZDmomYRHIg/maxresdefault.jpg
# Downloaded element 20 out of 49 total. URL: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Bugatti_Veyron_16.4_%E2%80%93_Frontansicht_%281%29%2C_5._April_2012%2C_D%C3%BCsseldorf.jpg/1200px-Bugatti_Veyron_16.4_%E2%80%93_Frontansicht_%281%29%2C_5._April_2012%2C_D%C3%BCsseldorf.jpg
# Downloaded element 21 out of 49 total. URL: https://di-uploads-pod20.dealerinspire.com/browardbugatti/uploads/2019/12/Yellow-Lamborghini-Aventador-20057295_xl-2015.jpg
# Downloaded element 22 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/
out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p1/se-image-fbf28c7252f24bee40d73108cc3bad71.jpg
# Downloaded element 46 out of 49 total. URL: https://media.wired.com/photos/5d56e7a245517600087f90a3/3:2/w_1280%2Cc_limit/Transpo_bugatti_02_CD_3I4-FRONT.jpg
# Downloaded element 47 out of 49 total. URL: https://www.bugatti.com/fileadmin/_processed_/sei/p54/se-image-204c6caaa086fafe35dc6199ebe10880.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 48 out of 49 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyJj3VWfVuU0sTi0BTfGAqwUGDHTd4uT1x5w&usqp=CAU

# %%
import os
import time
import requests
from selenium import webdriver


def fetch_image_urls(query: str, max_links_to_fetch: int, wd: webdriver, sleep_between_interactions: int = 1):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)

        # build the google query

    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)

        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")

        for img in thumbnail_results[results_start:number_results]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # extract image urls
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))

            image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(30)
            return
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)

    return image_urls


def persist_image(folder_path:str,url:str, counter):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        f = open(os.path.join(folder_path, 'jpg' + "_" + str(counter) + ".jpg"), 'wb')
        f.write(image_content)
        f.close()
        print(f"SUCCESS - saved {url} - as {folder_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")


def search_and_download(search_term: str, driver_path: str, target_path='./images', number_images=10):
    target_folder = os.path.join(target_path, '_'.join(search_term.lower().split(' ')))

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)

    counter = 0
    for elem in res:
        persist_image(target_folder, elem, counter)
        counter += 1


# How to execute this code
# Step 1 : pip install selenium. pillow, requests
# Step 2 : make sure you have chrome installed on your machine
# Step 3 : Check your chrome version ( go to three dot then help then about google chrome )
# Step 4 : Download the same chrome driver from here  " https://chromedriver.storage.googleapis.com/index.html "
# Step 5 : put it inside the same folder of this code


DRIVER_PATH = r'chromedriver.exe'
search_term = 'iNeuron'
# num of images you can pass it from here  by default it's 10 if you are not passing
#number_images = 50
search_and_download(search_term=search_term, driver_path=DRIVER_PATH, number_images=100)
# Out:
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:86: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
# Found: 100 search results. Extracting links from 0:100
# C:\Users\Vishal\anaconda3\envs\ImageScrapper\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
# Found: 100 image links, done!
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREfe7tgbZkASv--KrjHh20zlYfCIDgA0B2Fw&usqp=CAU - as ./images\ineuron
# SUCCESS - saved https